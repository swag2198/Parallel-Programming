# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# Collecting git+git://github.com/andreinechaev/nvcc4jupyter.git
#   Cloning git://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-brn2a3cw
#   Running command git clone -q git://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-brn2a3cw
# Building wheels for collected packages: NVCCPlugin
#   Building wheel for NVCCPlugin (setup.py) ... done
#   Created wheel for NVCCPlugin: filename=NVCCPlugin-0.0.2-cp36-none-any.whl size=4307 sha256=173eac38c0d5f517efa8e0cc131fb004e2c8392b4538e6cb235250c9a8e5b6bb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nq_86zln/wheels/10/c2/05/ca241da37bff77d60d31a9174f988109c61ba989e4d4650516
# Successfully built NVCCPlugin
# Installing collected packages: NVCCPlugin
# Successfully installed NVCCPlugin-0.0.2

# %%
# %load_ext nvcc_plugin
# Out:
# created output directory at /content/src
# Out bin /content/result.out

# %%
# %%cuda --name transpose.cu
# #include <cstdio>
# #include <cstdlib>
# #include <cmath>
# #include <ctime>
# #include <iostream>
#
# #include <cuda.h>
# #include <cuda_runtime.h>
#
# #define TILE_DIM 32
# #define W 16
#
# using namespace std;
#
# void printGPUproperties(cudaDeviceProp &devProp)
# {
#     printf("+++ Name : %s\n", devProp.name);
#     printf("    Total global memory : %ld bytes\n", devProp.totalGlobalMem);
#     printf("    Total shared memory per block : %ld bytes\n", devProp.sharedMemPerBlock);
#     printf("    Total shared memory per SM : %ld bytes\n", devProp.sharedMemPerMultiprocessor);
#     printf("    Memory bus width : %d bits\n", devProp.memoryBusWidth);
#     printf("    Memory clock rate : %d kHz\n", devProp.memoryClockRate);
#     printf("    Warp size : %d\n", devProp.warpSize);
# }
#
# void print_matrix(float *a, int m, int n, char c)
# {
#     if(c == 'i')
#         cout<<"Printing input matrix A = "<<endl;
#     else
#     {
#         cout<<"Printing transposed matrix AT = "<<endl;
#         m = m + n;
#         n = m - n;
#         m = m - n;
#     }
#     for(int i=0; i<m; i++)
#     {
#         for(int j=0; j<n; j++)
#             printf("%.2f ", a[n*i + j]);
#         cout<<endl;
#     }
#     cout<<endl;
# }
#
# int verify_result(float *AT, float *h_out, int m, int n)
# {
#     for(int i=0; i<n; i++)
#     {
#         for(int j=0; j<m; j++)
#         {
#             if(abs(AT[m*i + j] - h_out[m*i + j]) > 1e-6)
#             {
#                 cout<<"AT val = "<<AT[m*i + j]<<endl;
#                 cout<<"h_out val = "<<h_out[m*i + j]<<endl;
#                 return 0;
#             }
#         }
#     }
#     return 1;
# }
#
# void cpuTranspose(float *A, float *AT, int m, int n)
# {
#     for(int i=0; i<m; i++)
#         for(int j=0; j<n; j++)
#             AT[m*j + i] = A[n*i + j];
#
#     /*
#     for(int i=0; i<n; i++)
#         for(int j=0; j<m; j++)
#             AT[m*i + j] = A[n*j + i];
#     */
# }
#
# __global__ void gpuTransposeRow(float *d_in, float *d_out, int m, int n)
# {
#     int i = blockIdx.y * blockDim.y + threadIdx.y;
#     int j = blockIdx.x * blockDim.x + threadIdx.x;
#
#     //implement out[j][i] = in[i][j]
#     if(i < m && j < n)
#         d_out[m*j + i] = d_in[n*i + j];
# }
#
#
# __global__ void gpuTransposeCol(float *d_in, float *d_out, int m, int n)
# {
#     int i_o = blockIdx.x * blockDim.x + threadIdx.y;
#     int j_o = blockIdx.y * blockDim.y + threadIdx.x;
#
#     //implement out[i][j] = in[j][i]
#     if(i_o < n && j_o < m)
#     {
#         d_out[m*i_o + j_o] = d_in[n*j_o + i_o];
#         //printf("i = %d j = %d\n", i, j);
#     }
# }
#
#
# __global__ void gpuCopy(float *d_in, float *d_out, int m, int n)
# {
#     __shared__ float sharedcopy[TILE_DIM][TILE_DIM];
#
#     int i = blockIdx.y * blockDim.y + threadIdx.y;
#     int j = blockIdx.x * blockDim.x + threadIdx.x;
#
#     if(i < m && j < n)
#         sharedcopy[threadIdx.y][threadIdx.x] = d_in[n*i + j];
#     __syncthreads();
#
#     if(i < m && j < n)
#         d_out[n*i + j] = sharedcopy[threadIdx.y][threadIdx.x];
# }
#
# __global__ void gpuTransposeCoalesced(float *d_in, float *d_out, int m, int n)
# {
#     __shared__ float coal[TILE_DIM][TILE_DIM];
#
#     int i = blockIdx.y * blockDim.y + threadIdx.y;
#     int j = blockIdx.x * blockDim.x + threadIdx.x;
#
#     if(i < m && j < n)
#         coal[threadIdx.y][threadIdx.x] = d_in[n*i + j];
#     __syncthreads();
#
#     int i_o = blockIdx.x * blockDim.x + threadIdx.y;
#     int j_o = blockIdx.y * blockDim.y + threadIdx.x;
#
#     if(i_o < n && j_o < m)
#         d_out[m*i_o + j_o] = coal[threadIdx.x][threadIdx.y];
#
# }
#
# __global__ void gpuTransposeCoalescedNoBC(float *d_in, float *d_out, int m, int n)
# {
#     __shared__ float sharednbc[TILE_DIM][TILE_DIM+1];
#
#     int i = blockIdx.y * blockDim.y + threadIdx.y;
#     int j = blockIdx.x * blockDim.x + threadIdx.x;
#
#     if(i < m && j < n)
#         sharednbc[threadIdx.y][threadIdx.x] = d_in[n*i + j];
#     __syncthreads();
#
#     int i_o = blockIdx.x * blockDim.x + threadIdx.y;
#     int j_o = blockIdx.y * blockDim.y + threadIdx.x;
#
#     if(i_o < n && j_o < m)
#         d_out[m*i_o + j_o] = sharednbc[threadIdx.x][threadIdx.y];
# }
#
# __global__ void gpuTransposeCoalesced1D(float *d_in, float *d_out, int m, int n)
# {
#     extern __shared__ float shared[];
#
#     int i = blockIdx.y * blockDim.y + threadIdx.y;
#     int j = blockIdx.x * blockDim.x + threadIdx.x;
#
#     if(i < m && j < n)
#         shared[TILE_DIM*threadIdx.y + threadIdx.x] = d_in[n*i + j];
#     __syncthreads();
#
#     int i_o = blockIdx.x * blockDim.x + threadIdx.y;
#     int j_o = blockIdx.y * blockDim.y + threadIdx.x;
#
#     if(i_o < n && j_o < m)
#         d_out[m*i_o + j_o] = shared[TILE_DIM*threadIdx.x + threadIdx.y];
#
# }
#
# __global__ void gpuTransposeCoalesced1DNoBC(float *d_in, float *d_out, int m, int n)
# {
#     extern __shared__ float shared2[];
#
#     int i = blockIdx.y * blockDim.y + threadIdx.y;
#     int j = blockIdx.x * blockDim.x + threadIdx.x;
#
#     if(i < m && j < n)
#         shared2[(TILE_DIM+1)*threadIdx.y + threadIdx.x] = d_in[n*i + j];
#     __syncthreads();
#
#     int i_o = blockIdx.x * blockDim.x + threadIdx.y;
#     int j_o = blockIdx.y * blockDim.y + threadIdx.x;
#
#     if(i_o < n && j_o < m)
#         d_out[m*i_o + j_o] = shared2[(TILE_DIM+1)*threadIdx.x + threadIdx.y];
# }
#
#
# __global__ void gpuTransposeRect(float *d_in, float *d_out, int m, int n)
# {
#     __shared__ float rect[W][2*W];
#
#     int i = blockIdx.y * blockDim.y + threadIdx.y;
#     int j = blockIdx.x * blockDim.x + threadIdx.x;
#
#
#     if(i < m && j < n)
#         rect[threadIdx.y][threadIdx.x] = d_in[n*i + j];
#     __syncthreads();
#
#     int threadnum = threadIdx.y * blockDim.x + threadIdx.x;
#     int tidy_o = threadnum / blockDim.y;
#     int tidx_o = threadnum % blockDim.y;
#
#     int i_o = blockIdx.x * blockDim.x + tidy_o;
#     int j_o = blockIdx.y * blockDim.y + tidx_o;
#
#     if(i_o < n && j_o < m)
#         d_out[m*i_o + j_o] = rect[tidx_o][tidy_o];
# }
#
# __global__ void gpuTransposeRectNoBC(float *d_in, float *d_out, int m, int n)
# {
#     __shared__ float rect[W][2*W+1];
#
#     int i = blockIdx.y * blockDim.y + threadIdx.y;
#     int j = blockIdx.x * blockDim.x + threadIdx.x;
#
#
#     if(i < m && j < n)
#         rect[threadIdx.y][threadIdx.x] = d_in[n*i + j];
#     __syncthreads();
#
#     int threadnum = threadIdx.y * blockDim.x + threadIdx.x;
#     int tidy_o = threadnum / blockDim.y;
#     int tidx_o = threadnum % blockDim.y;
#
#     int i_o = blockIdx.x * blockDim.x + tidy_o;
#     int j_o = blockIdx.y * blockDim.y + tidx_o;
#
#     if(i_o < n && j_o < m)
#         d_out[m*i_o + j_o] = rect[tidx_o][tidy_o];
# }
#
#
# int main(int argc, char* argv[])
# {
#     cudaDeviceProp devprop;
#     cudaGetDeviceProperties(&devprop , 0);
#     printGPUproperties(devprop);
#
#     int m, n;
#     m = atoi(argv[1]); //num_rows
#     n = atoi(argv[2]); //num_cols
#
#     float *h_in, *h_out, *d_in, *d_out;; //for GPU computations
#     float *A, *AT; //for CPU computations
#
#     //Allocate Memory to cpu variables
#     h_in = (float *)malloc(m * n * sizeof(float));
#     h_out = (float *)malloc(m * n * sizeof(float));
#     A = (float *)malloc(m * n * sizeof(float));
#     AT = (float *)malloc(m * n * sizeof(float));
#
#     //Allocate Memory to gpu variables
#     cudaMalloc((void **)&d_in, m * n * sizeof(float));
#     cudaMalloc((void **)&d_out, m * n * sizeof(float));
#
#     for(int i=0; i<m; i++)
#     {
#         for(int j=0; j<n; j++)
#         {
#             //h_in[n*i + j] = (float(rand()) / (float(RAND_MAX)));
#             h_in[n*i + j] = n*i + j + 1;
#             A[n*i + j] = h_in[n*i + j];
#         }
#     }
#
#     //CPU transpose time
#     clock_t t1, t2;
#     t1 = clock();
#     cpuTranspose(A, AT, m, n);
#     t2 = clock();
#     print_matrix(A, m, n, 'i');
#     print_matrix(AT, m, n, 'o');
#     printf("+++ m = %d n = %d, CPU Time taken = %lf ms\n", m, n, ((double)(t2-t1)/(double)CLOCKS_PER_SEC) * 1000);
#
#
#     //GPU transpose row
#     cudaMemcpy(d_in, h_in, m * n *sizeof(float), cudaMemcpyHostToDevice);
#     //float grid_dim = ceil(sqrt(m*n / 1024.0));
#     //cout<<"grid dim = "<<grid_dim<<endl;
#     //dim3 grid(int(grid_dim), int(grid_dim), 1);
#     //dim3 block(32,32,1);
#     float ms;
#
#     dim3 block (TILE_DIM, TILE_DIM);
#     dim3 grid (( n + block.x - 1) / block .x, (m + block.y - 1) / block .y);
#
#     cout<<"+++ Block Dim = ("<<block.x<<", "<<block.y<<")"<<endl;
#     cout<<"    Grid Dim = ("<<grid.x<<", "<<grid.y<<")"<<endl;
#
#     cudaEvent_t c1, c2;
#     cudaEventCreate(&c1);
#     cudaEventCreate(&c2);
#
#     cudaEventRecord(c1);
#     gpuTransposeRow<<<grid, block>>>(d_in, d_out, m, n);
#     cudaEventRecord(c2);
#
#     cudaEventSynchronize(c2);
#     cudaEventElapsedTime(&ms, c1, c2);
#
#     cudaMemcpy(h_out, d_out, m * n *sizeof(float), cudaMemcpyDeviceToHost);
#     //print_matrix(h_out, m, n, 'o');
#     if(verify_result(AT, h_out, m, n))
#         printf("+++ m = %d n = %d, GPU Transpose (Read Rows, Store Cols) Time taken = %lf ms\n", m, n, ms);
#
#     //Reallocate used placeholders
#     cudaFree(d_out);
#     free(h_out);
#     cudaMalloc((void **)&d_out, m * n * sizeof(float));
#     //h_out = (float *)malloc(m * n * sizeof(float));
#     h_out = (float *)calloc(m * n,  sizeof(float));
#
#
#     //GPU transpose by columns
#     cudaEvent_t g1, g2;
#     cudaEventCreate(&g1);
#     cudaEventCreate(&g2);
#
#     cudaEventRecord(g1);
#     gpuTransposeCol<<<grid, block>>>(d_in, d_out, m, n);
#     cudaEventRecord(g2);
#     cudaEventSynchronize(g2);
#     cudaEventElapsedTime(&ms, g1, g2);
#
#     cudaMemcpy(h_out, d_out, m * n *sizeof(float), cudaMemcpyDeviceToHost);
#     //print_matrix(h_out, m, n, 'o');
#     if(verify_result(AT, h_out, m, n))
#         printf("+++ m = %d n = %d, GPU Transpose (Read Cols, Store Rows) Time taken = %lf ms\n", m, n, ms);
#
#     //Reallocate used placeholders
#     cudaFree(d_out);
#     free(h_out);
#     cudaMalloc((void **)&d_out, m * n * sizeof(float));
#     //h_out = (float *)malloc(m * n * sizeof(float));
#     h_out = (float *)calloc(m * n,  sizeof(float));
#
#
#     //GPU simple copy op
#     cudaEventRecord(g1);
#     gpuCopy<<<grid, block>>>(d_in, d_out, m, n);
#     cudaEventRecord(g2);
#     cudaEventSynchronize(g2);
#     cudaEventElapsedTime(&ms, g1, g2);
#
#     cudaMemcpy(h_out, d_out, m * n *sizeof(float), cudaMemcpyDeviceToHost);
#     //print_matrix(h_out, m, n, 'i');
#     //if(verify_result(AT, h_out, m, n))
#         printf("+++ m = %d n = %d, GPU simple copy (square sh. mem. no bank conflicts) Time taken = %lf ms [Reference Time]\n", m, n, ms);
#
#     //Reallocate used placeholders
#     cudaFree(d_out);
#     free(h_out);
#     cudaMalloc((void **)&d_out, m * n * sizeof(float));
#     //h_out = (float *)malloc(m * n * sizeof(float));
#     h_out = (float *)calloc(m * n,  sizeof(float));
#
#     //GPU transpose square shared memory
#     cudaEvent_t sh1, sh2;
#     cudaEventCreate(&sh1);
#     cudaEventCreate(&sh2);
#
#     //cout<<"calling sq sh"<<endl;
#     cudaEventRecord(sh1);
#     gpuTransposeCoalesced<<<grid, block>>>(d_in, d_out, m, n);
#     cudaEventRecord(sh2);
#     cudaEventSynchronize(sh2);
#     cudaEventElapsedTime(&ms, sh1, sh2);
#
#     cudaMemcpy(h_out, d_out, m * n *sizeof(float), cudaMemcpyDeviceToHost);
#     //print_matrix(h_out, m, n, 'o');
#     if(verify_result(AT, h_out, m, n))
#         printf("+++ m = %d n = %d, GPU Transpose (square sh. mem. with bank conflicts) Time taken = %lf ms\n", m, n, ms);
#
#     //Reallocate used placeholders
#     cudaFree(d_out);
#     free(h_out);
#     cudaMalloc((void **)&d_out, m * n * sizeof(float));
#     //h_out = (float *)malloc(m * n * sizeof(float));
#     h_out = (float *)calloc(m * n,  sizeof(float));
#
#     //GPU transpose square shared memory no bank conflicts
#     cudaEventRecord(sh1);
#     gpuTransposeCoalescedNoBC<<<grid, block>>>(d_in, d_out, m, n);
#     cudaEventRecord(sh2);
#     cudaEventSynchronize(sh2);
#     cudaEventElapsedTime(&ms, sh1, sh2);
#
#     cudaMemcpy(h_out, d_out, m * n *sizeof(float), cudaMemcpyDeviceToHost);
#     //print_matrix(h_out, m, n, 'o');
#     if(verify_result(AT, h_out, m, n))
#         printf("+++ m = %d n = %d, GPU Transpose (square sh. mem. no bank conflicts) Time taken = %lf ms\n", m, n, ms);
#
#     //Reallocate used placeholders
#     cudaFree(d_out);
#     free(h_out);
#     cudaMalloc((void **)&d_out, m * n * sizeof(float));
#     //h_out = (float *)malloc(m * n * sizeof(float));
#     h_out = (float *)calloc(m * n,  sizeof(float));
#
#     //GPU transpose 1D shared memory with bank conflicts
#     cudaEventRecord(sh1);
#     gpuTransposeCoalesced1D<<<grid, block, TILE_DIM * TILE_DIM * sizeof(float)>>>(d_in, d_out, m, n);
#     cudaEventRecord(sh2);
#     cudaEventSynchronize(sh2);
#     cudaEventElapsedTime(&ms, sh1, sh2);
#
#     cudaMemcpy(h_out, d_out, m * n *sizeof(float), cudaMemcpyDeviceToHost);
#     //print_matrix(h_out, m, n, 'o');
#     if(verify_result(AT, h_out, m, n))
#         printf("+++ m = %d n = %d, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = %lf ms\n", m, n, ms);
#
#     //Reallocate used placeholders
#     cudaFree(d_out);
#     free(h_out);
#     cudaMalloc((void **)&d_out, m * n * sizeof(float));
#     //h_out = (float *)malloc(m * n * sizeof(float));
#     h_out = (float *)calloc(m * n,  sizeof(float));
#
#     //GPU transpose 1D shared memory no bank conflicts
#     cudaEventRecord(sh1);
#     gpuTransposeCoalesced1DNoBC<<<grid, block, TILE_DIM * (TILE_DIM+1) * sizeof(float)>>>(d_in, d_out, m, n);
#     cudaEventRecord(sh2);
#     cudaEventSynchronize(sh2);
#     cudaEventElapsedTime(&ms, sh1, sh2);
#
#     cudaMemcpy(h_out, d_out, m * n *sizeof(float), cudaMemcpyDeviceToHost);
#     //print_matrix(h_out, m, n, 'o');
#     if(verify_result(AT, h_out, m, n))
#         printf("+++ m = %d n = %d, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = %lf ms\n", m, n, ms);
#
#
#     /*cout<<"Before freeing"<<endl;
#     for(int i=0; i<10; i++)
#         cout<<h_out[i]<<" ";
#     cout<<endl; */
#
#     //Reallocate used placeholders
#     cudaFree(d_out);
#     free(h_out);
#     cudaMalloc((void **)&d_out, m * n * sizeof(float));
#     h_out = (float *)calloc(m * n,  sizeof(float));
#
#     /*cout<<"After freeing"<<endl;
#     for(int i=0; i<10; i++)
#         cout<<h_out[i]<<" ";
#     cout<<endl; */
#
#     //GPU transpose 2d rect shared memory with bank conflicts
#     dim3 blockr (32, 16);
#     dim3 gridr (( n + blockr.x - 1) / blockr.x, (m + blockr.y - 1) / blockr.y);
#
#     float ms1;
#     cout<<"+++ Block Dim = ("<<blockr.x<<", "<<blockr.y<<")"<<endl;
#     cout<<"    Grid Dim = ("<<gridr.x<<", "<<gridr.y<<")"<<endl;
#
#     cudaEvent_t r1, r2;
#     cudaEventCreate(&r1);
#     cudaEventCreate(&r2);
#
#     cudaEventRecord(r1);
#     gpuTransposeRect<<<gridr, blockr>>>(d_in, d_out, m, n);
#     cudaEventRecord(r2);
#     cudaEventSynchronize(r2);
#     cudaEventElapsedTime(&ms1, r1, r2);
#
#     cudaMemcpy(h_out, d_out, m * n *sizeof(float), cudaMemcpyDeviceToHost);
#     //print_matrix(h_out, m, n, 'o');
#     if(verify_result(AT, h_out, m, n))
#         printf("+++ m = %d n = %d, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = %lf ms\n", m, n, ms1);
#     //printf("always prints+++ m = %d n = %d, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = %lf ms\n", m, n, ms1);
#
#     //Reallocate used placeholders
#     cudaFree(d_out);
#     free(h_out);
#     cudaMalloc((void **)&d_out, m * n * sizeof(float));
#     h_out = (float *)calloc(m * n,  sizeof(float));
#
#
#     //GPU transpose 2d rect shared memory with no bank conflicts
#
#     cudaEventRecord(r1);
#     gpuTransposeRectNoBC<<<gridr, blockr>>>(d_in, d_out, m, n);
#     cudaEventRecord(r2);
#     cudaEventSynchronize(r2);
#     cudaEventElapsedTime(&ms1, r1, r2);
#
#     cudaMemcpy(h_out, d_out, m * n *sizeof(float), cudaMemcpyDeviceToHost);
#     print_matrix(h_out, m, n, 'o');
#     if(verify_result(AT, h_out, m, n))
#         printf("+++ m = %d n = %d, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = %lf ms\n", m, n, ms1);
#
#
#     cudaFree(d_in);
#     cudaFree(d_out);
#     free(h_in);
#     free(h_out);
#     free(A);
#     free(AT);
#
#     return 0;
# }
# Out:
# 'File written in /content/src/transpose.cu'

# %%
# !nvcc /content/src/transpose.cu -o /content/src/transpose

# %%
# !/content/src/transpose 27 29
# Out:
# +++ Name : Tesla P100-PCIE-16GB
#     Total global memory : 17071734784 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 65536 bytes
#     Memory bus width : 4096 bits
#     Memory clock rate : 715000 kHz
#     Warp size : 32
# Printing input matrix A =
# 1.00 2.00 3.00 4.00 5.00 6.00 7.00 8.00 9.00 10.00 11.00 12.00 13.00 14.00 15.00 16.00 17.00 18.00 19.00 20.00 21.00 22.00 23.00 24.00 25.00 26.00 27.00 28.00 29.00
# 30.00 31.00 32.00 33.00 34.00 35.00 36.00 37.00 38.00 39.00 40.00 41.00 42.00 43.00 44.00 45.00 46.00 47.00 48.00 49.00 50.00 51.00 52.00 53.00 54.00 55.00 56.00 57.00 58.00
# 59.00 60.00 61.00 62.00 63.00 64.00 65.00 66.00 67.00 68.00 69.00 70.00 71.00 72.00 73.00 74.00 75.00 76.00 77.00 78.00 79.00 80.00 81.00 82.00 83.00 84.00 85.00 86.00 87.00
# 88.00 89.00 90.00 91.00 92.00 93.00 94.00 95.00 96.00 97.00 98.00 99.00 100.00 101.00 102.00 103.00 104.00 105.00 106.00 107.00 108.00 109.00 110.00 111.00 112.00 113.00 114.00 115.00 116.00
# 117.00 118.00 119.00 120.00 121.00 122.00 123.00 124.00 125.00 126.00 127.00 128.00 129.00 130.00 131.00 132.00 133.00 134.00 135.00 136.00 137.00 138.00 139.00 140.00 141.00 142.00 143.00 144.00 145.00
# 146.00 147.00 148.00 149.00 150.00 151.00 152.00 153.00 154.00 155.00 156.00 157.00 158.00 159.00 160.00 161.00 162.00 163.00 164.00 165.00 166.00 167.00 168.00 169.00 170.00 171.00 172.00 173.00 174.00
# 175.00 176.00 177.00 178.00 179.00 180.00 181.00 182.00 183.00 184.00 185.00 186.00 187.00 188.00 189.00 190.00 191.00 192.00 193.00 194.00 195.00 196.00 197.00 198.00 199.00 200.00 201.00 202.00 203.00
# 204.00 205.00 206.00 207.00 208.00 209.00 210.00 211.00 212.00 213.00 214.00 215.00 216.00 217.00 218.00 219.00 220.00 221.00 222.00 223.00 224.00 225.00 226.00 227.00 228.00 229.00 230.00 231.00 232.00
# 233.00 234.00 235.00 236.00 237.00 238.00 239.00 240.00 241.00 242.00 243.00 244.00 245.00 246.00 247.00 248.00 249.00 250.00 251.00 252.00 253.00 254.00 255.00 256.00 257.00 258.00 259.00 260.00 261.00
# 262.00 263.00 264.00 265.00 266.00 267.00 268.00 269.00 270.00 271.00 272.00 273.00 274.00 275.00 276.00 277.00 278.00 279.00 280.00 281.00 282.00 283.00 284.00 285.00 286.00 287.00 288.00 289.00 290.00
# 291.00 292.00 293.00 294.00 295.00 296.00 297.00 298.00 299.00 300.00 301.00 302.00 303.00 304.00 305.00 306.00 307.00 308.00 309.00 310.00 311.00 312.00 313.00 314.00 315.00 316.00 317.00 318.00 319.00
# 320.00 321.00 322.00 323.00 324.00 325.00 326.00 327.00 328.00 329.00 330.00 331.00 332.00 333.00 334.00 335.00 336.00 337.00 338.00 339.00 340.00 341.00 342.00 343.00 344.00 345.00 346.00 347.00 348.00
# 349.00 350.00 351.00 352.00 353.00 354.00 355.00 356.00 357.00 358.00 359.00 360.00 361.00 362.00 363.00 364.00 365.00 366.00 367.00 368.00 369.00 370.00 371.00 372.00 373.00 374.00 375.00 376.00 377.00
# 378.00 379.00 380.00 381.00 382.00 383.00 384.00 385.00 386.00 387.00 388.00 389.00 390.00 391.00 392.00 393.00 394.00 395.00 396.00 397.00 398.00 399.00 400.00 401.00 402.00 403.00 404.00 405.00 406.00
# 407.00 408.00 409.00 410.00 411.00 412.00 413.00 414.00 415.00 416.00 417.00 418.00 419.00 420.00 421.00 422.00 423.00 424.00 425.00 426.00 427.00 428.00 429.00 430.00 431.00 432.00 433.00 434.00 435.00
# 436.00 437.00 438.00 439.00 440.00 441.00 442.00 443.00 444.00 445.00 446.00 447.00 448.00 449.00 450.00 451.00 452.00 453.00 454.00 455.00 456.00 457.00 458.00 459.00 460.00 461.00 462.00 463.00 464.00
# 465.00 466.00 467.00 468.00 469.00 470.00 471.00 472.00 473.00 474.00 475.00 476.00 477.00 478.00 479.00 480.00 481.00 482.00 483.00 484.00 485.00 486.00 487.00 488.00 489.00 490.00 491.00 492.00 493.00
# 494.00 495.00 496.00 497.00 498.00 499.00 500.00 501.00 502.00 503.00 504.00 505.00 506.00 507.00 508.00 509.00 510.00 511.00 512.00 513.00 514.00 515.00 516.00 517.00 518.00 519.00 520.00 521.00 522.00
# 523.00 524.00 525.00 526.00 527.00 528.00 529.00 530.00 531.00 532.00 533.00 534.00 535.00 536.00 537.00 538.00 539.00 540.00 541.00 542.00 543.00 544.00 545.00 546.00 547.00 548.00 549.00 550.00 551.00
# 552.00 553.00 554.00 555.00 556.00 557.00 558.00 559.00 560.00 561.00 562.00 563.00 564.00 565.00 566.00 567.00 568.00 569.00 570.00 571.00 572.00 573.00 574.00 575.00 576.00 577.00 578.00 579.00 580.00
# 581.00 582.00 583.00 584.00 585.00 586.00 587.00 588.00 589.00 590.00 591.00 592.00 593.00 594.00 595.00 596.00 597.00 598.00 599.00 600.00 601.00 602.00 603.00 604.00 605.00 606.00 607.00 608.00 609.00
# 610.00 611.00 612.00 613.00 614.00 615.00 616.00 617.00 618.00 619.00 620.00 621.00 622.00 623.00 624.00 625.00 626.00 627.00 628.00 629.00 630.00 631.00 632.00 633.00 634.00 635.00 636.00 637.00 638.00
# 639.00 640.00 641.00 642.00 643.00 644.00 645.00 646.00 647.00 648.00 649.00 650.00 651.00 652.00 653.00 654.00 655.00 656.00 657.00 658.00 659.00 660.00 661.00 662.00 663.00 664.00 665.00 666.00 667.00
# 668.00 669.00 670.00 671.00 672.00 673.00 674.00 675.00 676.00 677.00 678.00 679.00 680.00 681.00 682.00 683.00 684.00 685.00 686.00 687.00 688.00 689.00 690.00 691.00 692.00 693.00 694.00 695.00 696.00
# 697.00 698.00 699.00 700.00 701.00 702.00 703.00 704.00 705.00 706.00 707.00 708.00 709.00 710.00 711.00 712.00 713.00 714.00 715.00 716.00 717.00 718.00 719.00 720.00 721.00 722.00 723.00 724.00 725.00
# 726.00 727.00 728.00 729.00 730.00 731.00 732.00 733.00 734.00 735.00 736.00 737.00 738.00 739.00 740.00 741.00 742.00 743.00 744.00 745.00 746.00 747.00 748.00 749.00 750.00 751.00 752.00 753.00 754.00
# 755.00 756.00 757.00 758.00 759.00 760.00 761.00 762.00 763.00 764.00 765.00 766.00 767.00 768.00 769.00 770.00 771.00 772.00 773.00 774.00 775.00 776.00 777.00 778.00 779.00 780.00 781.00 782.00 783.00
#
# Printing transposed matrix AT =
# 1.00 30.00 59.00 88.00 117.00 146.00 175.00 204.00 233.00 262.00 291.00 320.00 349.00 378.00 407.00 436.00 465.00 494.00 523.00 552.00 581.00 610.00 639.00 668.00 697.00 726.00 755.00
# 2.00 31.00 60.00 89.00 118.00 147.00 176.00 205.00 234.00 263.00 292.00 321.00 350.00 379.00 408.00 437.00 466.00 495.00 524.00 553.00 582.00 611.00 640.00 669.00 698.00 727.00 756.00
# 3.00 32.00 61.00 90.00 119.00 148.00 177.00 206.00 235.00 264.00 293.00 322.00 351.00 380.00 409.00 438.00 467.00 496.00 525.00 554.00 583.00 612.00 641.00 670.00 699.00 728.00 757.00
# 4.00 33.00 62.00 91.00 120.00 149.00 178.00 207.00 236.00 265.00 294.00 323.00 352.00 381.00 410.00 439.00 468.00 497.00 526.00 555.00 584.00 613.00 642.00 671.00 700.00 729.00 758.00
# 5.00 34.00 63.00 92.00 121.00 150.00 179.00 208.00 237.00 266.00 295.00 324.00 353.00 382.00 411.00 440.00 469.00 498.00 527.00 556.00 585.00 614.00 643.00 672.00 701.00 730.00 759.00
# 6.00 35.00 64.00 93.00 122.00 151.00 180.00 209.00 238.00 267.00 296.00 325.00 354.00 383.00 412.00 441.00 470.00 499.00 528.00 557.00 586.00 615.00 644.00 673.00 702.00 731.00 760.00
# 7.00 36.00 65.00 94.00 123.00 152.00 181.00 210.00 239.00 268.00 297.00 326.00 355.00 384.00 413.00 442.00 471.00 500.00 529.00 558.00 587.00 616.00 645.00 674.00 703.00 732.00 761.00
# 8.00 37.00 66.00 95.00 124.00 153.00 182.00 211.00 240.00 269.00 298.00 327.00 356.00 385.00 414.00 443.00 472.00 501.00 530.00 559.00 588.00 617.00 646.00 675.00 704.00 733.00 762.00
# 9.00 38.00 67.00 96.00 125.00 154.00 183.00 212.00 241.00 270.00 299.00 328.00 357.00 386.00 415.00 444.00 473.00 502.00 531.00 560.00 589.00 618.00 647.00 676.00 705.00 734.00 763.00
# 10.00 39.00 68.00 97.00 126.00 155.00 184.00 213.00 242.00 271.00 300.00 329.00 358.00 387.00 416.00 445.00 474.00 503.00 532.00 561.00 590.00 619.00 648.00 677.00 706.00 735.00 764.00
# 11.00 40.00 69.00 98.00 127.00 156.00 185.00 214.00 243.00 272.00 301.00 330.00 359.00 388.00 417.00 446.00 475.00 504.00 533.00 562.00 591.00 620.00 649.00 678.00 707.00 736.00 765.00
# 12.00 41.00 70.00 99.00 128.00 157.00 186.00 215.00 244.00 273.00 302.00 331.00 360.00 389.00 418.00 447.00 476.00 505.00 534.00 563.00 592.00 621.00 650.00 679.00 708.00 737.00 766.00
# 13.00 42.00 71.00 100.00 129.00 158.00 187.00 216.00 245.00 274.00 303.00 332.00 361.00 390.00 419.00 448.00 477.00 506.00 535.00 564.00 593.00 622.00 651.00 680.00 709.00 738.00 767.00
# 14.00 43.00 72.00 101.00 130.00 159.00 188.00 217.00 246.00 275.00 304.00 333.00 362.00 391.00 420.00 449.00 478.00 507.00 536.00 565.00 594.00 623.00 652.00 681.00 710.00 739.00 768.00
# 15.00 44.00 73.00 102.00 131.00 160.00 189.00 218.00 247.00 276.00 305.00 334.00 363.00 392.00 421.00 450.00 479.00 508.00 537.00 566.00 595.00 624.00 653.00 682.00 711.00 740.00 769.00
# 16.00 45.00 74.00 103.00 132.00 161.00 190.00 219.00 248.00 277.00 306.00 335.00 364.00 393.00 422.00 451.00 480.00 509.00 538.00 567.00 596.00 625.00 654.00 683.00 712.00 741.00 770.00
# 17.00 46.00 75.00 104.00 133.00 162.00 191.00 220.00 249.00 278.00 307.00 336.00 365.00 394.00 423.00 452.00 481.00 510.00 539.00 568.00 597.00 626.00 655.00 684.00 713.00 742.00 771.00
# 18.00 47.00 76.00 105.00 134.00 163.00 192.00 221.00 250.00 279.00 308.00 337.00 366.00 395.00 424.00 453.00 482.00 511.00 540.00 569.00 598.00 627.00 656.00 685.00 714.00 743.00 772.00
# 19.00 48.00 77.00 106.00 135.00 164.00 193.00 222.00 251.00 280.00 309.00 338.00 367.00 396.00 425.00 454.00 483.00 512.00 541.00 570.00 599.00 628.00 657.00 686.00 715.00 744.00 773.00
# 20.00 49.00 78.00 107.00 136.00 165.00 194.00 223.00 252.00 281.00 310.00 339.00 368.00 397.00 426.00 455.00 484.00 513.00 542.00 571.00 600.00 629.00 658.00 687.00 716.00 745.00 774.00
# 21.00 50.00 79.00 108.00 137.00 166.00 195.00 224.00 253.00 282.00 311.00 340.00 369.00 398.00 427.00 456.00 485.00 514.00 543.00 572.00 601.00 630.00 659.00 688.00 717.00 746.00 775.00
# 22.00 51.00 80.00 109.00 138.00 167.00 196.00 225.00 254.00 283.00 312.00 341.00 370.00 399.00 428.00 457.00 486.00 515.00 544.00 573.00 602.00 631.00 660.00 689.00 718.00 747.00 776.00
# 23.00 52.00 81.00 110.00 139.00 168.00 197.00 226.00 255.00 284.00 313.00 342.00 371.00 400.00 429.00 458.00 487.00 516.00 545.00 574.00 603.00 632.00 661.00 690.00 719.00 748.00 777.00
# 24.00 53.00 82.00 111.00 140.00 169.00 198.00 227.00 256.00 285.00 314.00 343.00 372.00 401.00 430.00 459.00 488.00 517.00 546.00 575.00 604.00 633.00 662.00 691.00 720.00 749.00 778.00
# 25.00 54.00 83.00 112.00 141.00 170.00 199.00 228.00 257.00 286.00 315.00 344.00 373.00 402.00 431.00 460.00 489.00 518.00 547.00 576.00 605.00 634.00 663.00 692.00 721.00 750.00 779.00
# 26.00 55.00 84.00 113.00 142.00 171.00 200.00 229.00 258.00 287.00 316.00 345.00 374.00 403.00 432.00 461.00 490.00 519.00 548.00 577.00 606.00 635.00 664.00 693.00 722.00 751.00 780.00
# 27.00 56.00 85.00 114.00 143.00 172.00 201.00 230.00 259.00 288.00 317.00 346.00 375.00 404.00 433.00 462.00 491.00 520.00 549.00 578.00 607.00 636.00 665.00 694.00 723.00 752.00 781.00
# 28.00 57.00 86.00 115.00 144.00 173.00 202.00 231.00 260.00 289.00 318.00 347.00 376.00 405.00 434.00 463.00 492.00 521.00 550.00 579.00 608.00 637.00 666.00 695.00 724.00 753.00 782.00
# 29.00 58.00 87.00 116.00 145.00 174.00 203.00 232.00 261.00 290.00 319.00 348.00 377.00 406.00 435.00 464.00 493.00 522.00 551.00 580.00 609.00 638.00 667.00 696.00 725.00 754.00 783.00
#
# +++ m = 27 n = 29, CPU Time taken = 0.004000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (1, 1)
# +++ m = 27 n = 29, GPU Transpose (Read Rows, Store Cols) Time taken = 0.019456 ms
# +++ m = 27 n = 29, GPU Transpose (Read Cols, Store Rows) Time taken = 0.012448 ms
# +++ m = 27 n = 29, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 0.011168 ms [Reference Time]
# +++ m = 27 n = 29, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 0.010784 ms
# +++ m = 27 n = 29, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 0.009984 ms
# +++ m = 27 n = 29, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 0.009952 ms
# +++ m = 27 n = 29, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 0.016608 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (1, 2)
# +++ m = 27 n = 29, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 0.012448 ms
# Printing transposed matrix AT =
# 1.00 30.00 59.00 88.00 117.00 146.00 175.00 204.00 233.00 262.00 291.00 320.00 349.00 378.00 407.00 436.00 465.00 494.00 523.00 552.00 581.00 610.00 639.00 668.00 697.00 726.00 755.00
# 2.00 31.00 60.00 89.00 118.00 147.00 176.00 205.00 234.00 263.00 292.00 321.00 350.00 379.00 408.00 437.00 466.00 495.00 524.00 553.00 582.00 611.00 640.00 669.00 698.00 727.00 756.00
# 3.00 32.00 61.00 90.00 119.00 148.00 177.00 206.00 235.00 264.00 293.00 322.00 351.00 380.00 409.00 438.00 467.00 496.00 525.00 554.00 583.00 612.00 641.00 670.00 699.00 728.00 757.00
# 4.00 33.00 62.00 91.00 120.00 149.00 178.00 207.00 236.00 265.00 294.00 323.00 352.00 381.00 410.00 439.00 468.00 497.00 526.00 555.00 584.00 613.00 642.00 671.00 700.00 729.00 758.00
# 5.00 34.00 63.00 92.00 121.00 150.00 179.00 208.00 237.00 266.00 295.00 324.00 353.00 382.00 411.00 440.00 469.00 498.00 527.00 556.00 585.00 614.00 643.00 672.00 701.00 730.00 759.00
# 6.00 35.00 64.00 93.00 122.00 151.00 180.00 209.00 238.00 267.00 296.00 325.00 354.00 383.00 412.00 441.00 470.00 499.00 528.00 557.00 586.00 615.00 644.00 673.00 702.00 731.00 760.00
# 7.00 36.00 65.00 94.00 123.00 152.00 181.00 210.00 239.00 268.00 297.00 326.00 355.00 384.00 413.00 442.00 471.00 500.00 529.00 558.00 587.00 616.00 645.00 674.00 703.00 732.00 761.00
# 8.00 37.00 66.00 95.00 124.00 153.00 182.00 211.00 240.00 269.00 298.00 327.00 356.00 385.00 414.00 443.00 472.00 501.00 530.00 559.00 588.00 617.00 646.00 675.00 704.00 733.00 762.00
# 9.00 38.00 67.00 96.00 125.00 154.00 183.00 212.00 241.00 270.00 299.00 328.00 357.00 386.00 415.00 444.00 473.00 502.00 531.00 560.00 589.00 618.00 647.00 676.00 705.00 734.00 763.00
# 10.00 39.00 68.00 97.00 126.00 155.00 184.00 213.00 242.00 271.00 300.00 329.00 358.00 387.00 416.00 445.00 474.00 503.00 532.00 561.00 590.00 619.00 648.00 677.00 706.00 735.00 764.00
# 11.00 40.00 69.00 98.00 127.00 156.00 185.00 214.00 243.00 272.00 301.00 330.00 359.00 388.00 417.00 446.00 475.00 504.00 533.00 562.00 591.00 620.00 649.00 678.00 707.00 736.00 765.00
# 12.00 41.00 70.00 99.00 128.00 157.00 186.00 215.00 244.00 273.00 302.00 331.00 360.00 389.00 418.00 447.00 476.00 505.00 534.00 563.00 592.00 621.00 650.00 679.00 708.00 737.00 766.00
# 13.00 42.00 71.00 100.00 129.00 158.00 187.00 216.00 245.00 274.00 303.00 332.00 361.00 390.00 419.00 448.00 477.00 506.00 535.00 564.00 593.00 622.00 651.00 680.00 709.00 738.00 767.00
# 14.00 43.00 72.00 101.00 130.00 159.00 188.00 217.00 246.00 275.00 304.00 333.00 362.00 391.00 420.00 449.00 478.00 507.00 536.00 565.00 594.00 623.00 652.00 681.00 710.00 739.00 768.00
# 15.00 44.00 73.00 102.00 131.00 160.00 189.00 218.00 247.00 276.00 305.00 334.00 363.00 392.00 421.00 450.00 479.00 508.00 537.00 566.00 595.00 624.00 653.00 682.00 711.00 740.00 769.00
# 16.00 45.00 74.00 103.00 132.00 161.00 190.00 219.00 248.00 277.00 306.00 335.00 364.00 393.00 422.00 451.00 480.00 509.00 538.00 567.00 596.00 625.00 654.00 683.00 712.00 741.00 770.00
# 17.00 46.00 75.00 104.00 133.00 162.00 191.00 220.00 249.00 278.00 307.00 336.00 365.00 394.00 423.00 452.00 481.00 510.00 539.00 568.00 597.00 626.00 655.00 684.00 713.00 742.00 771.00
# 18.00 47.00 76.00 105.00 134.00 163.00 192.00 221.00 250.00 279.00 308.00 337.00 366.00 395.00 424.00 453.00 482.00 511.00 540.00 569.00 598.00 627.00 656.00 685.00 714.00 743.00 772.00
# 19.00 48.00 77.00 106.00 135.00 164.00 193.00 222.00 251.00 280.00 309.00 338.00 367.00 396.00 425.00 454.00 483.00 512.00 541.00 570.00 599.00 628.00 657.00 686.00 715.00 744.00 773.00
# 20.00 49.00 78.00 107.00 136.00 165.00 194.00 223.00 252.00 281.00 310.00 339.00 368.00 397.00 426.00 455.00 484.00 513.00 542.00 571.00 600.00 629.00 658.00 687.00 716.00 745.00 774.00
# 21.00 50.00 79.00 108.00 137.00 166.00 195.00 224.00 253.00 282.00 311.00 340.00 369.00 398.00 427.00 456.00 485.00 514.00 543.00 572.00 601.00 630.00 659.00 688.00 717.00 746.00 775.00
# 22.00 51.00 80.00 109.00 138.00 167.00 196.00 225.00 254.00 283.00 312.00 341.00 370.00 399.00 428.00 457.00 486.00 515.00 544.00 573.00 602.00 631.00 660.00 689.00 718.00 747.00 776.00
# 23.00 52.00 81.00 110.00 139.00 168.00 197.00 226.00 255.00 284.00 313.00 342.00 371.00 400.00 429.00 458.00 487.00 516.00 545.00 574.00 603.00 632.00 661.00 690.00 719.00 748.00 777.00
# 24.00 53.00 82.00 111.00 140.00 169.00 198.00 227.00 256.00 285.00 314.00 343.00 372.00 401.00 430.00 459.00 488.00 517.00 546.00 575.00 604.00 633.00 662.00 691.00 720.00 749.00 778.00
# 25.00 54.00 83.00 112.00 141.00 170.00 199.00 228.00 257.00 286.00 315.00 344.00 373.00 402.00 431.00 460.00 489.00 518.00 547.00 576.00 605.00 634.00 663.00 692.00 721.00 750.00 779.00
# 26.00 55.00 84.00 113.00 142.00 171.00 200.00 229.00 258.00 287.00 316.00 345.00 374.00 403.00 432.00 461.00 490.00 519.00 548.00 577.00 606.00 635.00 664.00 693.00 722.00 751.00 780.00
# 27.00 56.00 85.00 114.00 143.00 172.00 201.00 230.00 259.00 288.00 317.00 346.00 375.00 404.00 433.00 462.00 491.00 520.00 549.00 578.00 607.00 636.00 665.00 694.00 723.00 752.00 781.00
# 28.00 57.00 86.00 115.00 144.00 173.00 202.00 231.00 260.00 289.00 318.00 347.00 376.00 405.00 434.00 463.00 492.00 521.00 550.00 579.00 608.00 637.00 666.00 695.00 724.00 753.00 782.00
# 29.00 58.00 87.00 116.00 145.00 174.00 203.00 232.00 261.00 290.00 319.00 348.00 377.00 406.00 435.00 464.00 493.00 522.00 551.00 580.00 609.00 638.00 667.00 696.00 725.00 754.00 783.00
#
# +++ m = 27 n = 29, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 0.009984 ms

# %%
# !/content/src/transpose 8192 8192
# Out:
# +++ Name : Tesla P100-PCIE-16GB
#     Total global memory : 17071734784 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 65536 bytes
#     Memory bus width : 4096 bits
#     Memory clock rate : 715000 kHz
#     Warp size : 32
# +++ m = 8192 n = 8192, CPU Time taken = 2006.693000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (256, 256)
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 4.361120 ms
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 1.262272 ms
# +++ m = 8192 n = 8192, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 1.287872 ms [Reference Time]
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 1.887552 ms
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 1.262528 ms
# +++ m = 8192 n = 8192, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 1.892704 ms
# +++ m = 8192 n = 8192, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 1.265312 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (256, 512)
# +++ m = 8192 n = 8192, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 1.675584 ms
# +++ m = 8192 n = 8192, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 1.507200 ms

# %%
# !/content/src/transpose 8192 8192
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 8192 n = 8192, CPU Time taken = 2178.484000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (256, 256)
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 12.237888 ms
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 21.925728 ms
# +++ m = 8192 n = 8192, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 5.525760 ms [Reference Time]
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 9.915456 ms
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 6.010240 ms
# +++ m = 8192 n = 8192, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 9.919840 ms
# +++ m = 8192 n = 8192, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 6.001280 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (256, 512)
# +++ m = 8192 n = 8192, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 6.869920 ms
# +++ m = 8192 n = 8192, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 6.298176 ms

# %%
# !cuda-memcheck /content/src/transpose 843 94949
# Out:
# ========= CUDA-MEMCHECK
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 843 n = 94949, CPU Time taken = 2615.322000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (2968, 27)
# +++ m = 843 n = 94949, GPU Transpose (Read Rows, Store Cols) Time taken = 139.082169 ms
# +++ m = 843 n = 94949, GPU Transpose (Read Cols, Store Rows) Time taken = 122.883652 ms
# +++ m = 843 n = 94949, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 213.194687 ms [Reference Time]
# +++ m = 843 n = 94949, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 219.416473 ms
# +++ m = 843 n = 94949, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 221.048218 ms
# +++ m = 843 n = 94949, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 220.823364 ms
# +++ m = 843 n = 94949, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 221.494812 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (2968, 53)
# +++ m = 843 n = 94949, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 219.362747 ms
# +++ m = 843 n = 94949, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 219.579803 ms
# ========= ERROR SUMMARY: 0 errors

# %%
# !/content/src/transpose 8192 8192
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 8192 n = 8192, CPU Time taken = 2436.365000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (256, 256)
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 12.265568 ms
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 21.971775 ms
# +++ m = 8192 n = 8192, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 5.544192 ms [Reference Time]
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 9.974976 ms
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 6.020640 ms
# +++ m = 8192 n = 8192, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 9.979776 ms
# +++ m = 8192 n = 8192, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 6.014304 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (256, 512)
# +++ m = 8192 n = 8192, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 6.873312 ms
# +++ m = 8192 n = 8192, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 6.297312 ms

# %%
# !cuda-memcheck /content/src/transpose 843 94949
# Out:
# ========= CUDA-MEMCHECK
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 843 n = 94949, CPU Time taken = 2724.855000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (2968, 27)
# +++ m = 843 n = 94949, GPU Transpose (Read Rows, Store Cols) Time taken = 139.099716 ms
# +++ m = 843 n = 94949, GPU Transpose (Read Cols, Store Rows) Time taken = 122.914818 ms
# +++ m = 843 n = 94949, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 213.377563 ms [Reference Time]
# +++ m = 843 n = 94949, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 220.063431 ms
# +++ m = 843 n = 94949, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 221.479034 ms
# +++ m = 843 n = 94949, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 220.827423 ms
# +++ m = 843 n = 94949, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 221.524704 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (2968, 53)
# +++ m = 843 n = 94949, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 219.738022 ms
# +++ m = 843 n = 94949, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 219.768188 ms
# ========= ERROR SUMMARY: 0 errors

# %%
# !cat file.txt
# Out:
# cat: file.txt: No such file or directory

# %%
# !/content/src/transpose 10 1
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 10 n = 1, CPU Time taken = 0.001000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (1, 1)
# +++ m = 10 n = 1, GPU Transpose (Read Rows, Store Cols) Time taken = 0.122080 ms
# +++ m = 10 n = 1, GPU Transpose (Read Cols, Store Rows) Time taken = 0.023456 ms
# +++ m = 10 n = 1, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 0.022880 ms [Reference Time]
# +++ m = 10 n = 1, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 0.020576 ms
# +++ m = 10 n = 1, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 0.022208 ms
# +++ m = 10 n = 1, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 0.040960 ms
# +++ m = 10 n = 1, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 0.022304 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (1, 1)
# +++ m = 10 n = 1, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 0.022752 ms
# +++ m = 10 n = 1, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 0.038048 ms

# %%
# !/content/src/transpose 32 32
# Out:
# +++ Name : Tesla T4
#     Total global memory : 15812263936 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 65536 bytes
#     Total registers per block : 65536 bytes
#     Memory bus width : 256 bits
#     Memory clock rate : 5001000 kHz
#     Warp size : 32
# +++ m = 32 n = 32, CPU Time taken = 0.006000 ms
# +++ m = 32 n = 32, GPU Transpose (Read Rows, Store Cols) Time taken = 0.024064 ms
# +++ m = 32 n = 32, GPU Transpose (Read Cols, Store Rows) Time taken = 0.015488 ms
# +++ m = 32 n = 32, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 0.012096 ms [Reference Time]
# +++ m = 32 n = 32, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 0.013472 ms
# +++ m = 32 n = 32, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 0.011328 ms
# +++ m = 32 n = 32, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 0.012096 ms
# +++ m = 32 n = 32, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 0.010016 ms
# Block Dim = (16, 32)
# Grid Dim = (2, 1)
# AT val = 1
# h_out val = 0
# always prints+++ m = 32 n = 32, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 0.000000 ms

# %%
# !/content/src/transpose 8192 8192
# Out:
# +++ Name : Tesla P4
#     Total global memory : 7981694976 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 98304 bytes
#     Total registers per block : 65536 bytes
#     Memory bus width : 256 bits
#     Memory clock rate : 3003000 kHz
#     Warp size : 32
# +++ m = 8192 n = 8192, CPU Time taken = 1954.697000 ms
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 9.793824 ms
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 6.728000 ms
# +++ m = 8192 n = 8192, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 4.287712 ms [Reference Time]
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 6.149280 ms
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 4.586656 ms
# +++ m = 8192 n = 8192, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 6.158496 ms
# +++ m = 8192 n = 8192, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 4.584096 ms
# Block Dim = (16, 32)
# Grid Dim = (512, 256)
# +++ m = 8192 n = 8192, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 4.584096 ms

# %%
# !/content/src/transpose 10000 10000
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 10000 n = 10000, CPU Time taken = 3091.290000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (313, 313)
# +++ m = 10000 n = 10000, GPU Transpose (Read Rows, Store Cols) Time taken = 19.008160 ms
# +++ m = 10000 n = 10000, GPU Transpose (Read Cols, Store Rows) Time taken = 33.899361 ms
# +++ m = 10000 n = 10000, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 9.110240 ms [Reference Time]
# +++ m = 10000 n = 10000, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 15.127936 ms
# +++ m = 10000 n = 10000, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 10.157280 ms
# +++ m = 10000 n = 10000, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 15.119616 ms
# +++ m = 10000 n = 10000, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 10.156576 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (313, 625)
# +++ m = 10000 n = 10000, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 10.934176 ms
# +++ m = 10000 n = 10000, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 10.156768 ms

# %%
# !/content/src/transpose 8192 8192
# Out:
# +++ Name : Tesla P100-PCIE-16GB
#     Total global memory : 17071734784 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 65536 bytes
#     Total registers per block : 65536 bytes
#     Warp size : 32
# +++ m = 8192 n = 8192, CPU Time taken = 2216.960000 ms
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 4.330208 ms
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 1.257792 ms
# +++ m = 8192 n = 8192, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 1.149312 ms [Reference Time]
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 1.902656 ms
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 1.244512 ms
# +++ m = 8192 n = 8192, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 1.859136 ms
# +++ m = 8192 n = 8192, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 1.245984 ms

# %%
# !/content/src/transpose 4096 4096
# Out:
# +++ Name : Tesla T4
#     Total global memory : 15812263936 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 65536 bytes
#     Total registers per block : 65536 bytes
#     Memory bus width : 256 bits
#     Memory clock rate : 5001000 kHz
#     Warp size : 32
# +++ m = 4096 n = 4096, CPU Time taken = 355.001000 ms
# +++ m = 4096 n = 4096, GPU Transpose (Read Rows, Store Cols) Time taken = 2.933312 ms
# +++ m = 4096 n = 4096, GPU Transpose (Read Cols, Store Rows) Time taken = 1.963744 ms
# +++ m = 4096 n = 4096, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 0.819424 ms [Reference Time]
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 2.084960 ms
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 0.865824 ms
# +++ m = 4096 n = 4096, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 2.084224 ms
# +++ m = 4096 n = 4096, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 0.869248 ms

# %%
# !/content/src/transpose 4096 4096
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Total registers per block : 65536 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 4096 n = 4096, CPU Time taken = 553.292000 ms
# +++ m = 4096 n = 4096, GPU Transpose (Read Rows, Store Cols) Time taken = 3.076288 ms
# +++ m = 4096 n = 4096, GPU Transpose (Read Cols, Store Rows) Time taken = 5.397504 ms
# +++ m = 4096 n = 4096, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 1.315744 ms [Reference Time]
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 2.455616 ms
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 1.463104 ms
# +++ m = 4096 n = 4096, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 2.457504 ms
# +++ m = 4096 n = 4096, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 1.460768 ms

# %%
# !nvprof --events warps_launched,local_load --metrics all /content/src/transpose 8192 8192 #Tesla K-80
# Out:
# ==240== NVPROF is profiling process 240, command: /content/src/transpose 8192 8192
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Total registers per block : 65536 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 8192 n = 8192, CPU Time taken = 2340.207000 ms
# ==240== Some kernel(s) will be replayed on device 0 in order to collect all events/metrics.
# ==240== Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (1 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (2 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (3 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (4 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (5 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (6 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (7 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (8 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (9 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (10 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (11 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (12 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (13 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (15 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (16 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (17 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (18 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (19 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (20 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (21 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (22 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (23 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (24 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (25 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (26 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (27 of 60)...
# 	rocache_gld_inst_8bit
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (28 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (29 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (30 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (31 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (32 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (33 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (34 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (35 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (36 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (37 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (38 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (39 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (40 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (41 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (42 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (43 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (44 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (45 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (46 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (47 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (48 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (49 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (50 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (52 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (53 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (54 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (55 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (56 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (57 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (58 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (59 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==240==
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (60 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==240==
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 3054.894043 ms
# ==240== Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (2 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (3 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (4 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (5 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (6 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (7 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (8 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==240==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (9 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (10 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (11 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (12 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (13 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (14 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (15 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (16 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (17 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (18 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (19 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (20 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (21 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (22 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (23 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (24 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (25 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (26 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (27 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (28 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (29 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (30 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (31 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (32 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (33 of 60)...
# 	rocache_gld_inst_8bit
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (34 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (35 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (36 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (37 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (38 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (39 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (40 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (41 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (42 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (43 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (44 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (45 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (46 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (47 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (48 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (49 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (50 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (51 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (52 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (53 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (54 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (56 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (57 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (58 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (59 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (60 of 60)...
# 	1 internal events
# ==240==
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 3451.239502 ms
# ==240== Replaying kernel "gpuCopy(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (2 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (3 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (4 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (5 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (6 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (7 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (8 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (9 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (10 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (11 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (12 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (13 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (14 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (15 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (16 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (18 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (19 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (20 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (21 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (22 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (23 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==240==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (24 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (25 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (26 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (27 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (28 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (29 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (30 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (31 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (32 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (33 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (34 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (35 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (36 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==240==
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (37 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (38 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (39 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (40 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (41 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (42 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (43 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (44 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (45 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (46 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (47 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (48 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (49 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (50 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (51 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (52 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (53 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (54 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (56 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (57 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (58 of 60)...
# 	rocache_gld_inst_8bit
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (59 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (60 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==240==
# Replaying kernel "gpuCopy(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 2615.073975 ms [Reference Time]
# ==240== Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (2 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (3 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (4 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (5 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (6 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (7 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (8 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (9 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (10 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (11 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (12 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (13 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (14 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (15 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (16 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (18 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (19 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (20 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (21 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (22 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (23 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (24 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (25 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (26 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (27 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (28 of 60)...
# 	rocache_gld_inst_8bit
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (29 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (30 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (31 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (33 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (34 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (35 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (36 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (37 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (38 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (39 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (41 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (42 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (43 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (44 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (45 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (46 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (47 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (48 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (49 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (50 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (51 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (52 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (53 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==240==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (54 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (55 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (56 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (57 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (58 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (59 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (60 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==240==
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 3253.849121 ms
# ==240== Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (1 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (2 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (3 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (4 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (5 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (6 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (7 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (8 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (9 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (10 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (11 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (12 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (13 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (14 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (15 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (16 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==240==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (17 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (18 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (19 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (20 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (21 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (22 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (23 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (24 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (25 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (26 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (27 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (28 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==240==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (29 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (30 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (31 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (32 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (33 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (34 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==240==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (35 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (36 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (37 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (38 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (39 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (40 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (41 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (42 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (43 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (44 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (45 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (46 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (47 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (48 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (49 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (50 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (52 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (53 of 60)...
# 	2 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (54 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (55 of 60)...
# 	rocache_gld_inst_8bit
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (56 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (57 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (58 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (59 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (60 of 60)...
# 	4 internal events
# ==240==
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 3066.791260 ms
# ==240== Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (2 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==240==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (3 of 60)...
# 	rocache_gld_inst_8bit
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (4 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (5 of 60)...
# 	4 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (6 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (7 of 60)...
# 	1 internal events
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (8 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (9 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==240==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (10 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==240==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (11 of 60)...
# 	4 internal events
# ==240==
#
#
# ...
#           1                      dram_read_throughput                         Device Memory Read Throughput  31.835GB/s  31.835GB/s  31.835GB/s
#           1                     dram_write_throughput                        Device Memory Write Throughput  32.313GB/s  32.313GB/s  32.313GB/s
#           1                            gst_throughput                               Global Store Throughput  25.851GB/s  25.851GB/s  25.851GB/s
#           1                            gld_throughput                                Global Load Throughput  25.851GB/s  25.851GB/s  25.851GB/s
#           1                     local_replay_overhead                    Local Memory Cache Replay Overhead    0.000000    0.000000    0.000000
#           1                         shared_efficiency                              Shared Memory Efficiency       5.88%       5.88%       5.88%
#           1                            gld_efficiency                         Global Memory Load Efficiency     100.00%     100.00%     100.00%
#           1                            gst_efficiency                        Global Memory Store Efficiency     100.00%     100.00%     100.00%
#           1                       l2_l1_read_hit_rate                                L2 Hit Rate (L1 Reads)       0.00%       0.00%       0.00%
#           1                  l2_texture_read_hit_rate                           L2 Hit Rate (Texture Reads)       0.00%       0.00%       0.00%
#           1                     l2_l1_read_throughput                              L2 Throughput (L1 Reads)  25.851GB/s  25.851GB/s  25.851GB/s
#           1                l2_texture_read_throughput                         L2 Throughput (Texture Reads)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                     local_memory_overhead                                 Local Memory Overhead       0.00%       0.00%       0.00%
#           1                 warp_execution_efficiency                             Warp Execution Efficiency     100.00%     100.00%     100.00%
#           1               nc_gld_requested_throughput         Requested Non-Coherent Global Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                                issued_ipc                                            Issued IPC    1.498122    1.498122    1.498122
#           1                             inst_per_warp                                 Instructions per warp   34.000000   34.000000   34.000000
#           1                    issue_slot_utilization                                Issue Slot Utilization      33.04%      33.04%      33.04%
#           1       local_load_transactions_per_request            Local Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1      local_store_transactions_per_request           Local Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1      shared_load_transactions_per_request           Shared Memory Load Transactions Per Request   16.000000   16.000000   16.000000
#           1     shared_store_transactions_per_request          Shared Memory Store Transactions Per Request    1.000001    1.000001    1.000001
#           1              gld_transactions_per_request                  Global Load Transactions Per Request    1.000000    1.000000    1.000000
#           1              gst_transactions_per_request                 Global Store Transactions Per Request    1.000000    1.000000    1.000000
#           1                   local_load_transactions                               Local Load Transactions           0           0           0
#           1                  local_store_transactions                              Local Store Transactions           0           0           0
#           1                  shared_load_transactions                              Shared Load Transactions    33554432    33554432    33554432
#           1                 shared_store_transactions                             Shared Store Transactions     2097154     2097154     2097154
#           1                          gld_transactions                              Global Load Transactions     2097152     2097152     2097152
#           1                          gst_transactions                             Global Store Transactions     2097152     2097152     2097152
#           1                  sysmem_read_transactions                       System Memory Read Transactions           0           0           0
#           1                 sysmem_write_transactions                      System Memory Write Transactions           1           1           1
#           1                    tex_cache_transactions                            Texture Cache Transactions           0           0           0
#           1                    dram_read_transactions                       Device Memory Read Transactions    10330406    10330406    10330406
#           1                   dram_write_transactions                      Device Memory Write Transactions    10485778    10485778    10485778
#           1                      l2_read_transactions                                  L2 Read Transactions     8388691     8388691     8388691
#           1                     l2_write_transactions                                 L2 Write Transactions     8388625     8388625     8388625
#           1                     local_load_throughput                          Local Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    local_store_throughput                         Local Memory Store Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    shared_load_throughput                         Shared Memory Load Throughput  827.22GB/s  827.22GB/s  827.22GB/s
#           1                   shared_store_throughput                        Shared Memory Store Throughput  51.701GB/s  51.701GB/s  51.701GB/s
#           1                        l2_read_throughput                                 L2 Throughput (Reads)  25.851GB/s  25.851GB/s  25.851GB/s
#           1                       l2_write_throughput                                L2 Throughput (Writes)  25.851GB/s  25.851GB/s  25.851GB/s
#           1                    sysmem_read_throughput                         System Memory Read Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   sysmem_write_throughput                        System Memory Write Throughput  3.2305KB/s  3.2305KB/s  3.2295KB/s
#           1         warp_nonpred_execution_efficiency              Warp Non-Predicated Execution Efficiency      94.12%      94.12%      94.12%
#           1                                 cf_issued                      Issued Control-Flow Instructions    10533252    10533252    10533252
#           1                               cf_executed                    Executed Control-Flow Instructions    10485760    10485760    10485760
#           1                               ldst_issued                        Issued Load/Store Instructions    42216620    42216620    42216620
#           1                             ldst_executed                      Executed Load/Store Instructions     8388608     8388608     8388608
#           1                             flop_count_sp           Floating Point Operations(Single Precision)           0           0           0
#           1                         flop_count_sp_add       Floating Point Operations(Single Precision Add)           0           0           0
#           1                         flop_count_sp_mul        Floating Point Operation(Single Precision Mul)           0           0           0
#           1                         flop_count_sp_fma       Floating Point Operations(Single Precision FMA)           0           0           0
#           1                             flop_count_dp           Floating Point Operations(Double Precision)           0           0           0
#           1                         flop_count_dp_add       Floating Point Operations(Double Precision Add)           0           0           0
#           1                         flop_count_dp_mul       Floating Point Operations(Double Precision Mul)           0           0           0
#           1                         flop_count_dp_fma       Floating Point Operations(Double Precision FMA)           0           0           0
#           1                     flop_count_sp_special   Floating Point Operations(Single Precision Special)           0           0           0
#           1                          stall_inst_fetch              Issue Stall Reasons (Instructions Fetch)       2.59%       2.59%       2.59%
#           1                     stall_exec_dependency            Issue Stall Reasons (Execution Dependency)      12.39%      12.39%      12.39%
#           1                   stall_memory_dependency                    Issue Stall Reasons (Data Request)      17.20%      17.20%      17.20%
#           1                             stall_texture                         Issue Stall Reasons (Texture)       0.00%       0.00%       0.00%
#           1                                stall_sync                 Issue Stall Reasons (Synchronization)       5.16%       5.16%       5.16%
#           1                               stall_other                           Issue Stall Reasons (Other)       1.46%       1.46%       1.46%
#           1                     l1_shared_utilization                          L1/Shared Memory Utilization     Mid (6)     Mid (6)     Mid (6)
#           1                            l2_utilization                                  L2 Cache Utilization     Low (1)     Low (1)     Low (1)
#           1                           tex_utilization                             Texture Cache Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                          dram_utilization                             Device Memory Utilization     Low (3)     Low (3)     Low (3)
#           1                        sysmem_utilization                             System Memory Utilization     Low (1)     Low (1)     Low (1)
#           1                       ldst_fu_utilization                  Load/Store Function Unit Utilization     Mid (6)     Mid (6)     Mid (6)
#           1                        alu_fu_utilization                  Arithmetic Function Unit Utilization     Low (3)     Low (3)     Low (3)
#           1                         cf_fu_utilization                Control-Flow Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                        tex_fu_utilization                     Texture Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                             inst_executed                                 Instructions Executed    71303168    71303168    71303168
#           1                               inst_issued                                   Instructions Issued   107277578   107277578   107277578
#           1                               issue_slots                                           Issue Slots    94646849    94646849    94646849
#           1                     nc_l2_read_throughput                    L2 Throughput (Non-Coherent Reads)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   nc_l2_read_transactions                     L2 Non-Coherent Read Transactions           0           0           0
#           1                  nc_cache_global_hit_rate                          Non-Coherent Global Hit Rate       0.00%       0.00%       0.00%
#           1                         nc_gld_throughput            Non-Coherent Global Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                         nc_gld_efficiency                   Non-Coherent Global Load Efficiency       0.00%       0.00%       0.00%
#           1                      l2_atomic_throughput                       L2 Throughput (Atomic requests)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                                inst_fp_32                               FP Instructions(Single)           0           0           0
#           1                                inst_fp_64                               FP Instructions(Double)           0           0           0
#           1                              inst_integer                                  Integer Instructions  1207959552  1207959552  1207959552
#           1                          inst_bit_convert                              Bit-Convert Instructions           0           0           0
#           1                              inst_control                             Control-Flow Instructions    67108864    67108864    67108864
#           1                        inst_compute_ld_st                               Load/Store Instructions   268435456   268435456   268435456
#           1                                 inst_misc                                     Misc Instructions   536870912   536870912   536870912
#           1           inst_inter_thread_communication                             Inter-Thread Instructions           0           0           0
#           1                    atomic_replay_overhead                                Atomic Replay Overhead    0.000000    0.000000    0.000000
#           1                       atomic_transactions                                   Atomic Transactions           0           0           0
#           1           atomic_transactions_per_request                       Atomic Transactions Per Request    0.000000    0.000000    0.000000
#           1                   sysmem_read_utilization                        System Memory Read Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                  sysmem_write_utilization                       System Memory Write Utilization     Low (1)     Low (1)     Low (1)
#           1                   l2_l1_read_transactions               L2 Read Transactions (L1 read requests)     8388608     8388608     8388608
#           1                  l2_l1_write_transactions             L2 Write Transactions (L1 write requests)     8388608     8388608     8388608
#           1                  l2_tex_read_transactions                       L2 Transactions (Texture Reads)           0           0           0
#           1                    l2_l1_write_throughput                             L2 Throughput (L1 Writes)  25.851GB/s  25.851GB/s  25.851GB/s
#           1                    l2_atomic_transactions                     L2 Transactions (Atomic requests)           0           0           0
#           1                          ecc_transactions                                      ECC Transactions     4037844     4037844     4037844
#           1                            ecc_throughput                                        ECC Throughput  12.443GB/s  12.443GB/s  12.443GB/s
#           1                           stall_pipe_busy                       Issue Stall Reasons (Pipe Busy)      35.15%      35.15%      35.15%
#           1          stall_constant_memory_dependency              Issue Stall Reasons (Immediate constant)       0.01%       0.01%       0.01%
#           1                        flop_sp_efficiency                          FLOP Efficiency(Peak Single)       0.00%       0.00%       0.00%
#           1                        flop_dp_efficiency                          FLOP Efficiency(Peak Double)       0.00%       0.00%       0.00%
#           1                     stall_memory_throttle                 Issue Stall Reasons (Memory Throttle)      13.92%      13.92%      13.92%
#           1                        stall_not_selected                    Issue Stall Reasons (Not Selected)      12.12%      12.12%      12.12%
#           1                  eligible_warps_per_cycle                       Eligible Warps Per Active Cycle    7.921209    7.921209    7.921209
#           1                         atomic_throughput                                     Atomic Throughput  0.00000B/s  0.00000B/s  0.00000B/s

# %%
# !nvprof --events warps_launched,local_load --metrics all /content/src/transpose 8192 8192 #time mismatch in row and col
# Out:
# ==598== NVPROF is profiling process 598, command: /content/src/transpose 8192 8192
# +++ Name : Tesla P100-PCIE-16GB
#     Total global memory : 17071734784 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM :65536 bytes
#     Total registers per block : 65536 bytes
#     Warp size : 32
# +++ m = 8192 n = 8192, CPU Time taken = 1950.756000 ms
# ==598== Some kernel(s) will be replayed on device 0 in order to collect all events/metrics.
# ==598== Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (1 of 60)...
# 	active_cycles
# 	elapsed_cycles_sm
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	active_warps
# 	shared_ld_transactions
# 	shared_st_transactions
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (2 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp1_read_sectors
# 	fb1_subp1_read_sectors
# 	fb_subp1_write_sectors
# 	fb1_subp1_write_sectors
# 	inst_executed
# 	not_predicated_off_thread_inst_executed
# 	inst_issued1
# 	inst_issued2
# 	l2_subp0_write_sysmem_sector_queries
# 	l2_subp1_write_sysmem_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (3 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (4 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (5 of 60)...
# 	active_cycles
# 	inst_issued1
# 	inst_issued2
# 	2 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (6 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp0_read_sectors
# 	fb1_subp0_read_sectors
# 	fb_subp0_write_sectors
# 	fb1_subp0_write_sectors
# 	inst_executed
# 	branch
# 	divergent_branch
# 	thread_inst_executed
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (7 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (8 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (9 of 60)...
# 	tex0_cache_sector_queries
# 	tex1_cache_sector_queries
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (10 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (11 of 60)...
# 	global_load
# 	l2_subp0_write_tex_hit_sectors
# 	l2_subp1_write_tex_hit_sectors
# 	7 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (12 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (13 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (14 of 60)...
# 	elapsed_cycles_pm
# 	local_store
# 	l2_subp0_total_write_sector_queries
# 	l2_subp1_total_write_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (15 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (16 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (18 of 60)...
# 	1 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (19 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (20 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (21 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (22 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (23 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (24 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (25 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (26 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (27 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (28 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (29 of 60)...
# 	warps_launched
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (30 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (31 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (33 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (34 of 60)...
# 	8 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (35 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (36 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (37 of 60)...
# 	1 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (38 of 60)...
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (39 of 60)...
# 	gred_count
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (40 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (41 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (42 of 60)...
# 	elapsed_cycles_pm
# 	global_store
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (43 of 60)...
# 	10 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (44 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (45 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (46 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (47 of 60)...
# 	elapsed_cycles_pm
# 	global_atom_cas
# 	atom_count
# 	l2_subp0_read_tex_hit_sectors
# 	l2_subp1_read_tex_hit_sectors
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (48 of 60)...
# 	elapsed_cycles_pm
# 	local_load
# 	l2_subp0_total_read_sector_queries
# 	l2_subp1_total_read_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (49 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (50 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (52 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (53 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (54 of 60)...
# 	elapsed_cycles_pm
# 	inst_executed_shared_atom_cas
# 	shared_atom
# 	shared_load
# 	shared_store
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (56 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (57 of 60)...
# 	5 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (58 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (59 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (60 of 60)...
# 	4 internal events
# ==598==
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 1664.261475 ms
# ==598== Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (1 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (2 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (3 of 60)...
# 	elapsed_cycles_pm
# 	inst_executed_shared_atom_cas
# 	shared_atom
# 	shared_load
# 	shared_store
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (4 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (5 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (6 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (7 of 60)...
# 	warps_launched
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (8 of 60)...
# 	5 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (9 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp0_read_sectors
# 	fb1_subp0_read_sectors
# 	fb_subp0_write_sectors
# 	fb1_subp0_write_sectors
# 	inst_executed
# 	branch
# 	divergent_branch
# 	thread_inst_executed
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (10 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (11 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (12 of 60)...
# 	8 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (13 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (15 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp1_read_sectors
# 	fb1_subp1_read_sectors
# 	fb_subp1_write_sectors
# 	fb1_subp1_write_sectors
# 	inst_executed
# 	not_predicated_off_thread_inst_executed
# 	inst_issued1
# 	inst_issued2
# 	l2_subp0_write_sysmem_sector_queries
# 	l2_subp1_write_sysmem_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (16 of 60)...
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (18 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (19 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (20 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (21 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (22 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (23 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (24 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (25 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (26 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (27 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (28 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (29 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (30 of 60)...
# 	active_cycles
# 	inst_issued1
# 	inst_issued2
# 	2 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (31 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (32 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (33 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (34 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (35 of 60)...
# 	elapsed_cycles_pm
# 	global_atom_cas
# 	atom_count
# 	l2_subp0_read_tex_hit_sectors
# 	l2_subp1_read_tex_hit_sectors
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (36 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (37 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (38 of 60)...
# 	elapsed_cycles_pm
# 	local_store
# 	l2_subp0_total_write_sector_queries
# 	l2_subp1_total_write_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (39 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (41 of 60)...
# 	1 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (42 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (44 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (45 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (46 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (47 of 60)...
# 	active_cycles
# 	elapsed_cycles_sm
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	active_warps
# 	shared_ld_transactions
# 	shared_st_transactions
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (48 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (49 of 60)...
# 	10 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (50 of 60)...
# 	elapsed_cycles_pm
# 	local_load
# 	l2_subp0_total_read_sector_queries
# 	l2_subp1_total_read_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (52 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (53 of 60)...
# 	1 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (54 of 60)...
# 	elapsed_cycles_pm
# 	global_store
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (56 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (57 of 60)...
# 	tex0_cache_sector_queries
# 	tex1_cache_sector_queries
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (58 of 60)...
# 	global_load
# 	l2_subp0_write_tex_hit_sectors
# 	l2_subp1_write_tex_hit_sectors
# 	7 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (59 of 60)...
# 	gred_count
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (60 of 60)...
# 	4 internal events
# ==598==
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 1223.361694 ms
# ==598== Replaying kernel "gpuCopy(float*, float*, int, int)" (1 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (2 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (3 of 60)...
# 	10 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (4 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (5 of 60)...
# 	1 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (6 of 60)...
# 	elapsed_cycles_pm
# 	global_atom_cas
# 	atom_count
# 	l2_subp0_read_tex_hit_sectors
# 	l2_subp1_read_tex_hit_sectors
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (7 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (8 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp1_read_sectors
# 	fb1_subp1_read_sectors
# 	fb_subp1_write_sectors
# 	fb1_subp1_write_sectors
# 	inst_executed
# 	not_predicated_off_thread_inst_executed
# 	inst_issued1
# 	inst_issued2
# 	l2_subp0_write_sysmem_sector_queries
# 	l2_subp1_write_sysmem_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (9 of 60)...
# 	elapsed_cycles_pm
# 	global_store
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (10 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (11 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (12 of 60)...
# 	1 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (13 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (14 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (15 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (16 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (18 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (19 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp0_read_sectors
# 	fb1_subp0_read_sectors
# 	fb_subp0_write_sectors
# 	fb1_subp0_write_sectors
# 	inst_executed
# 	branch
# 	divergent_branch
# 	thread_inst_executed
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (20 of 60)...
# 	active_cycles
# 	inst_issued1
# 	inst_issued2
# 	2 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (21 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (22 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (23 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (24 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (25 of 60)...
# 	gred_count
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (26 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (27 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (28 of 60)...
# 	global_load
# 	l2_subp0_write_tex_hit_sectors
# 	l2_subp1_write_tex_hit_sectors
# 	7 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (29 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (30 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (31 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (33 of 60)...
# 	elapsed_cycles_pm
# 	local_load
# 	l2_subp0_total_read_sector_queries
# 	l2_subp1_total_read_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (34 of 60)...
# 	elapsed_cycles_pm
# 	local_store
# 	l2_subp0_total_write_sector_queries
# 	l2_subp1_total_write_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (35 of 60)...
# 	8 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (36 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (37 of 60)...
# 	active_cycles
# 	elapsed_cycles_sm
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	active_warps
# 	shared_ld_transactions
# 	shared_st_transactions
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (38 of 60)...
# 	tex0_cache_sector_queries
# 	tex1_cache_sector_queries
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (39 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (41 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (42 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (43 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (44 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (45 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (46 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (47 of 60)...
# 	warps_launched
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (48 of 60)...
# 	5 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (49 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (50 of 60)...
# 	elapsed_cycles_pm
# 	inst_executed_shared_atom_cas
# 	shared_atom
# 	shared_load
# 	shared_store
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (52 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (53 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (54 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (56 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (57 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (58 of 60)...
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (59 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (60 of 60)...
# 	4 internal events
# ==598==
# Replaying kernel "gpuCopy(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 1243.762695 ms
# ==598== Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (1 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (2 of 60)...
# 	warps_launched
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (3 of 60)...
# 	elapsed_cycles_pm
# 	local_load
# 	l2_subp0_total_read_sector_queries
# 	l2_subp1_total_read_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (4 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (5 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (6 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (7 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (8 of 60)...
# 	active_cycles
# 	inst_issued1
# 	inst_issued2
# 	2 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (9 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (10 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (11 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (12 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (13 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (15 of 60)...
# 	elapsed_cycles_pm
# 	global_store
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (16 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (18 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (19 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (20 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (21 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (22 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (23 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (24 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (25 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (26 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (27 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (28 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (29 of 60)...
# 	8 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (30 of 60)...
# 	elapsed_cycles_pm
# 	inst_executed_shared_atom_cas
# 	shared_atom
# 	shared_load
# 	shared_store
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (31 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (33 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (34 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (35 of 60)...
# 	elapsed_cycles_pm
# 	global_atom_cas
# 	atom_count
# 	l2_subp0_read_tex_hit_sectors
# 	l2_subp1_read_tex_hit_sectors
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (36 of 60)...
# 	10 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (37 of 60)...
# 	active_cycles
# 	elapsed_cycles_sm
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	active_warps
# 	shared_ld_transactions
# 	shared_st_transactions
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (38 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (39 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (40 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp1_read_sectors
# 	fb1_subp1_read_sectors
# 	fb_subp1_write_sectors
# 	fb1_subp1_write_sectors
# 	inst_executed
# 	not_predicated_off_thread_inst_executed
# 	inst_issued1
# 	inst_issued2
# 	l2_subp0_write_sysmem_sector_queries
# 	l2_subp1_write_sysmem_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (41 of 60)...
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (42 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (44 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (45 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (46 of 60)...
# 	1 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (47 of 60)...
# 	global_load
# 	l2_subp0_write_tex_hit_sectors
# 	l2_subp1_write_tex_hit_sectors
# 	7 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (48 of 60)...
# 	elapsed_cycles_pm
# 	local_store
# 	l2_subp0_total_write_sector_queries
# 	l2_subp1_total_write_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (49 of 60)...
# 	tex0_cache_sector_queries
# 	tex1_cache_sector_queries
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (50 of 60)...
# 	5 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (52 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (53 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (54 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (56 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp0_read_sectors
# 	fb1_subp0_read_sectors
# 	fb_subp0_write_sectors
# 	fb1_subp0_write_sectors
# 	inst_executed
# 	branch
# 	divergent_branch
# 	thread_inst_executed
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (57 of 60)...
# 	gred_count
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (58 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (59 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (60 of 60)...
# 	1 internal events
# ==598==
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 1308.668335 ms
# ==598== Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (1 of 60)...
# 	warps_launched
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (2 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (3 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (4 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (5 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (6 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (7 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (8 of 60)...
# 	elapsed_cycles_pm
# 	inst_executed_shared_atom_cas
# 	shared_atom
# 	shared_load
# 	shared_store
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (9 of 60)...
# 	8 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (10 of 60)...
# 	gred_count
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (11 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (12 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (13 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (14 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (15 of 60)...
# 	elapsed_cycles_pm
# 	global_atom_cas
# 	atom_count
# 	l2_subp0_read_tex_hit_sectors
# 	l2_subp1_read_tex_hit_sectors
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (16 of 60)...
# 	1 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (17 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (18 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (19 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (20 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (21 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (22 of 60)...
# 	tex0_cache_sector_queries
# 	tex1_cache_sector_queries
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (23 of 60)...
# 	elapsed_cycles_pm
# 	local_load
# 	l2_subp0_total_read_sector_queries
# 	l2_subp1_total_read_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (24 of 60)...
# 	global_load
# 	l2_subp0_write_tex_hit_sectors
# 	l2_subp1_write_tex_hit_sectors
# 	7 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (25 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (26 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (27 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (28 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (29 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (30 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (31 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (32 of 60)...
# 	1 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (33 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (34 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (35 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (36 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (37 of 60)...
# 	active_cycles
# 	elapsed_cycles_sm
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	active_warps
# 	shared_ld_transactions
# 	shared_st_transactions
# ==598==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (38 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (39 of 60)...
# 	5 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (41 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp1_read_sectors
# 	fb1_subp1_read_sectors
# 	fb_subp1_write_sectors
# 	fb1_subp1_write_sectors
# 	inst_executed
# 	not_predicated_off_thread_inst_executed
# 	inst_issued1
# 	inst_issued2
# 	l2_subp0_write_sysmem_sector_queries
# 	l2_subp1_write_sysmem_sector_queries
# 	4 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (42 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (43 of 60)...
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	7 internal events
# ==598==
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (44 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (45 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp0_read_sectors
# 	fb1_subp0_read_sectors
# 	fb_subp0_write_sectors
# 	fb1_subp0_write_sectors
# 	inst_executed
# 	branch
# 	divergent_branch
# 	thread_inst_executed
# 	6 internal events
# ==598==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (46 of 60)...
# 	elapsed_cycles_pm
# 	local_store
# 	l2_subp0_total_write_sector_queries
# 	l2_subp1_total_write_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (47 of 60)...
# 	active_cycles
# 	inst_issued1
# 	inst_issued2
# 	2 internal events
# ==598==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (48 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (49 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (50 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (51 of 60)...
# 	elapsed_cycles_pm
# 	global_store
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	5 internal events
# ==598==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (52 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (53 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (54 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (56 of 60)...
# 	2 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (57 of 60)...
# 	10 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (58 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (59 of 60)...
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (60 of 60)...
# 	active_cycles
# 	4 internal events
# ==598==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 1275.379883 ms
# ==598== Profiling application: /content/src/transpose 8192 8192
# ==598== Profiling result:
# ==598== Event result:
# Invocations                                Event Name         Min         Max         Avg       Total
# Device "Tesla P100-PCIE-16GB (0)"
#     Kernel: gpuTransposeCol(float*, float*, int, int)
#           1                            warps_launched     2097152     2097152     2097152     2097152
#           1                                local_load           0           0           0           0
#     Kernel: gpuTransposeCoalescedNoBC(float*, float*, int, int)
#           1                            warps_launched     2097152     2097152     2097152     2097152
#           1                                local_load           0           0           0           0
#     Kernel: gpuCopy(float*, float*, int, int)
#           1                            warps_launched     2097152     2097152     2097152     2097152
#           1                                local_load           0           0           0           0
#     Kernel: gpuTransposeRow(float*, float*, int, int)
#           1                            warps_launched     2097152     2097152     2097152     2097152
#           1                                local_load           0           0           0           0
#     Kernel: gpuTransposeCoalesced(float*, float*, int, int)
#           1                            warps_launched     2097152     2097152     2097152     2097152
#           1                                local_load           0           0           0           0
#
# ==598== Metric result:
# Invocations                               Metric Name                                                    Metric Description         Min         Max         Avg
# Device "Tesla P100-PCIE-16GB (0)"
#     Kernel: gpuTransposeCol(float*, float*, int, int)
#           1                             inst_per_warp                                                 Instructions per warp   30.000000   30.000000   30.000000
#           1                         branch_efficiency                                                     Branch Efficiency     100.00%     100.00%     100.00%
#           1                 warp_execution_efficiency                                             Warp Execution Efficiency     100.00%     100.00%     100.00%
#           1         warp_nonpred_execution_efficiency                              Warp Non-Predicated Execution Efficiency      96.67%      96.67%      96.67%
#           1                      inst_replay_overhead                                           Instruction Replay Overhead    0.000195    0.000195    0.000195
#           1      shared_load_transactions_per_request                           Shared Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1     shared_store_transactions_per_request                          Shared Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1       local_load_transactions_per_request                            Local Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1      local_store_transactions_per_request                           Local Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1              gld_transactions_per_request                                  Global Load Transactions Per Request   16.000001   16.000001   16.000001
#           1              gst_transactions_per_request                                 Global Store Transactions Per Request    4.000000    4.000000    4.000000
#           1                 shared_store_transactions                                             Shared Store Transactions           0           0           0
#           1                  shared_load_transactions                                              Shared Load Transactions           0           0           0
#           1                   local_load_transactions                                               Local Load Transactions           0           0           0
#           1                  local_store_transactions                                              Local Store Transactions           0           0           0
#           1                          gld_transactions                                              Global Load Transactions    33554434    33554434    33554434
#           1                          gst_transactions                                             Global Store Transactions     8388608     8388608     8388608
#           1                  sysmem_read_transactions                                       System Memory Read Transactions           0           0           0
#           1                 sysmem_write_transactions                                      System Memory Write Transactions           5           5           5
#           1                      l2_read_transactions                                                  L2 Read Transactions     8388869     8388869     8388869
#           1                     l2_write_transactions                                                 L2 Write Transactions     8388628     8388628     8388628
#           1                    dram_read_transactions                                       Device Memory Read Transactions     8388620     8388620     8388620
#           1                   dram_write_transactions                                      Device Memory Write Transactions     8391596     8391596     8391596
#           1                           global_hit_rate                                     Global Hit Rate in unified l1/tex      87.50%      87.50%      87.50%
#           1                            local_hit_rate                                                        Local Hit Rate       0.00%       0.00%       0.00%
#           1                  gld_requested_throughput                                      Requested Global Load Throughput  218.75GB/s  218.75GB/s  218.75GB/s
#           1                  gst_requested_throughput                                     Requested Global Store Throughput  218.75GB/s  218.75GB/s  218.75GB/s
# ...
#           1                          dram_utilization                                             Device Memory Utilization     Mid (5)     Mid (5)     Mid (5)
#           1                        sysmem_utilization                                             System Memory Utilization     Low (1)     Low (1)     Low (1)
#           1                          stall_inst_fetch                              Issue Stall Reasons (Instructions Fetch)       1.66%       1.66%       1.66%
#           1                     stall_exec_dependency                            Issue Stall Reasons (Execution Dependency)      16.32%      16.32%      16.32%
#           1                   stall_memory_dependency                                    Issue Stall Reasons (Data Request)      22.30%      22.30%      22.30%
#           1                             stall_texture                                         Issue Stall Reasons (Texture)       0.00%       0.00%       0.00%
#           1                                stall_sync                                 Issue Stall Reasons (Synchronization)      13.66%      13.66%      13.66%
#           1                               stall_other                                           Issue Stall Reasons (Other)      42.54%      42.54%      42.54%
#           1          stall_constant_memory_dependency                              Issue Stall Reasons (Immediate constant)       0.04%       0.04%       0.04%
#           1                           stall_pipe_busy                                       Issue Stall Reasons (Pipe Busy)       0.78%       0.78%       0.78%
#           1                         shared_efficiency                                              Shared Memory Efficiency       6.06%       6.06%       6.06%
#           1                                inst_fp_32                                               FP Instructions(Single)           0           0           0
#           1                                inst_fp_64                                               FP Instructions(Double)           0           0           0
#           1                              inst_integer                                                  Integer Instructions  1744830464  1744830464  1744830464
#           1                          inst_bit_convert                                              Bit-Convert Instructions           0           0           0
#           1                              inst_control                                             Control-Flow Instructions    67108864    67108864    67108864
#           1                        inst_compute_ld_st                                               Load/Store Instructions   335544320   335544320   335544320
#           1                                 inst_misc                                                     Misc Instructions   536870912   536870912   536870912
#           1           inst_inter_thread_communication                                             Inter-Thread Instructions           0           0           0
#           1                               issue_slots                                                           Issue Slots    83900203    83900203    83900203
#           1                                 cf_issued                                      Issued Control-Flow Instructions     2097152     2097152     2097152
#           1                               cf_executed                                    Executed Control-Flow Instructions     2097152     2097152     2097152
#           1                               ldst_issued                                        Issued Load/Store Instructions    33554432    33554432    33554432
#           1                             ldst_executed                                      Executed Load/Store Instructions    23068672    23068672    23068672
#           1                       atomic_transactions                                                   Atomic Transactions           0           0           0
#           1           atomic_transactions_per_request                                       Atomic Transactions Per Request    0.000000    0.000000    0.000000
#           1                      l2_atomic_throughput                                       L2 Throughput (Atomic requests)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    l2_atomic_transactions                                     L2 Transactions (Atomic requests)           0           0           0
#           1                  l2_tex_read_transactions                                       L2 Transactions (Texture Reads)     8388608     8388608     8388608
#           1                     stall_memory_throttle                                 Issue Stall Reasons (Memory Throttle)       0.77%       0.77%       0.77%
#           1                        stall_not_selected                                    Issue Stall Reasons (Not Selected)       1.93%       1.93%       1.93%
#           1                 l2_tex_write_transactions                                      L2 Transactions (Texture Writes)     8388608     8388608     8388608
#           1                             flop_count_hp                             Floating Point Operations(Half Precision)           0           0           0
#           1                         flop_count_hp_add                         Floating Point Operations(Half Precision Add)           0           0           0
#           1                         flop_count_hp_mul                          Floating Point Operation(Half Precision Mul)           0           0           0
#           1                         flop_count_hp_fma                         Floating Point Operations(Half Precision FMA)           0           0           0
#           1                                inst_fp_16                                                 HP Instructions(Half)           0           0           0
#           1                                       ipc                                                          Executed IPC    0.691471    0.691471    0.691471
#           1                                issued_ipc                                                            Issued IPC    0.690983    0.690983    0.690983
#           1                    issue_slot_utilization                                                Issue Slot Utilization      34.55%      34.55%      34.55%
#           1                             sm_efficiency                                               Multiprocessor Activity      99.73%      99.73%      99.73%
#           1                        achieved_occupancy                                                    Achieved Occupancy    0.810211    0.810211    0.810211
#           1                  eligible_warps_per_cycle                                       Eligible Warps Per Active Cycle    1.679819    1.679819    1.679819
#           1                        shared_utilization                                             Shared Memory Utilization     Mid (6)     Mid (6)     Mid (6)
#           1                            l2_utilization                                                  L2 Cache Utilization     Low (2)     Low (2)     Low (2)
#           1                           tex_utilization                                             Unified Cache Utilization     Low (1)     Low (1)     Low (1)
#           1                       ldst_fu_utilization                                  Load/Store Function Unit Utilization     Low (2)     Low (2)     Low (2)
#           1                         cf_fu_utilization                                Control-Flow Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                        tex_fu_utilization                                     Texture Function Unit Utilization     Low (2)     Low (2)     Low (2)
#           1                    special_fu_utilization                                     Special Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1             half_precision_fu_utilization                              Half-Precision Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1           single_precision_fu_utilization                            Single-Precision Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1           double_precision_fu_utilization                            Double-Precision Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                        flop_hp_efficiency                                            FLOP Efficiency(Peak Half)       0.00%       0.00%       0.00%
#           1                        flop_sp_efficiency                                          FLOP Efficiency(Peak Single)       0.00%       0.00%       0.00%
#           1                        flop_dp_efficiency                                          FLOP Efficiency(Peak Double)       0.00%       0.00%       0.00%
#           1                   sysmem_read_utilization                                        System Memory Read Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                  sysmem_write_utilization                                       System Memory Write Utilization     Low (1)     Low (1)     Low (1)
#           1               pcie_total_data_transmitted                                           PCIe Total Data Transmitted           0           0           0
#           1                  pcie_total_data_received                                              PCIe Total Data Received           0           0           0
#           1                inst_executed_global_loads                              Warp level instructions for global loads     2097152     2097152     2097152
#           1                 inst_executed_local_loads                               Warp level instructions for local loads           0           0           0
#           1                inst_executed_shared_loads                              Warp level instructions for shared loads     2097152     2097152     2097152
#           1               inst_executed_surface_loads                             Warp level instructions for surface loads           0           0           0
#           1               inst_executed_global_stores                             Warp level instructions for global stores     2097152     2097152     2097152
#           1                inst_executed_local_stores                              Warp level instructions for local stores           0           0           0
#           1               inst_executed_shared_stores                             Warp level instructions for shared stores     2097152     2097152     2097152
#           1              inst_executed_surface_stores                            Warp level instructions for surface stores           0           0           0
#           1              inst_executed_global_atomics                  Warp level instructions for global atom and atom cas           0           0           0
#           1           inst_executed_global_reductions                         Warp level instructions for global reductions           0           0           0
#           1             inst_executed_surface_atomics                 Warp level instructions for surface atom and atom cas           0           0           0
#           1          inst_executed_surface_reductions                        Warp level instructions for surface reductions           0           0           0
#           1              inst_executed_shared_atomics                  Warp level shared instructions for atom and atom CAS           0           0           0
#           1                     inst_executed_tex_ops                                   Warp level instructions for texture           0           0           0
#           1                      l2_global_load_bytes       Bytes read from L2 for misses in Unified Cache for global loads   268435456   268435456   268435456
#           1                       l2_local_load_bytes        Bytes read from L2 for misses in Unified Cache for local loads           0           0           0
#           1                     l2_surface_load_bytes      Bytes read from L2 for misses in Unified Cache for surface loads           0           0           0
#           1                           dram_read_bytes                                Total bytes read from DRAM to L2 cache   268436352   268436352   268436352
#           1                          dram_write_bytes                             Total bytes written from L2 cache to DRAM   268540544   268540544   268540544
#           1               l2_local_global_store_bytes   Bytes written to L2 from Unified Cache for local and global stores.   268435456   268435456   268435456
#           1                 l2_global_reduction_bytes          Bytes written to L2 from Unified cache for global reductions           0           0           0
#           1              l2_global_atomic_store_bytes             Bytes written to L2 from Unified cache for global atomics           0           0           0
#           1                    l2_surface_store_bytes            Bytes written to L2 from Unified Cache for surface stores.           0           0           0
#           1                l2_surface_reduction_bytes         Bytes written to L2 from Unified Cache for surface reductions           0           0           0
#           1             l2_surface_atomic_store_bytes    Bytes transferred between Unified Cache and L2 for surface atomics           0           0           0
#           1                      global_load_requests              Total number of global load requests from Multiprocessor     8388608     8388608     8388608
#           1                       local_load_requests               Total number of local load requests from Multiprocessor           0           0           0
#           1                     surface_load_requests             Total number of surface load requests from Multiprocessor           0           0           0
#           1                     global_store_requests             Total number of global store requests from Multiprocessor     8388608     8388608     8388608
#           1                      local_store_requests              Total number of local store requests from Multiprocessor           0           0           0
#           1                    surface_store_requests            Total number of surface store requests from Multiprocessor           0           0           0
#           1                    global_atomic_requests            Total number of global atomic requests from Multiprocessor           0           0           0
#           1                 global_reduction_requests         Total number of global reduction requests from Multiprocessor           0           0           0
#           1                   surface_atomic_requests           Total number of surface atomic requests from Multiprocessor           0           0           0
#           1                surface_reduction_requests        Total number of surface reduction requests from Multiprocessor           0           0           0
#           1                         sysmem_read_bytes                                              System Memory Read Bytes           0           0           0
#           1                        sysmem_write_bytes                                             System Memory Write Bytes         160         160         160
#           1                           l2_tex_hit_rate                                                     L2 Cache Hit Rate       0.00%       0.00%       0.00%
#           1                     texture_load_requests             Total number of texture Load requests from Multiprocessor           0           0           0
#           1                     unique_warps_launched                                              Number of warps launched     2097152     2097152     2097152

# %%
# !nvprof --events warps_launched,local_load --metrics all /content/src/transpose 8192 8192 #all four, no time mismatch in row and col
# Out:
# ==1588== NVPROF is profiling process 1588, command: /content/src/transpose 8192 8192
# +++ m = 8192 n = 8192, CPU Time taken = 2339.930000 ms
# grid dim = 256
# ==1588== Some kernel(s) will be replayed on device 0 in order to collect all events/metrics.
# ==1588== Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (1 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (2 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (3 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (4 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (5 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (6 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (7 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (8 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (9 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (10 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (11 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (12 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (13 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (14 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (15 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (16 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (17 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (18 of 60)...
# 	rocache_gld_inst_8bit
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (19 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (20 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (21 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (22 of 60)...
# 	l2_subp1_write_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1588==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (23 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (24 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (25 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (26 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (27 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (28 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (29 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1588==
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (30 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1588==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (31 of 60)...
# 	l2_subp0_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (32 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (33 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (34 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (35 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (36 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (37 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (38 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (39 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (40 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	active_cycles
# 	10 internal events
# ==1588==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (41 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (42 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (44 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (45 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (46 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (47 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (48 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (49 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (50 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (51 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (52 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (53 of 60)...
# 	elapsed_cycles_sm
# 	l2_subp0_read_l1_sector_queries
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (54 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (55 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (56 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (57 of 60)...
# 	l2_subp2_write_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (58 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (59 of 60)...
# 	l2_subp3_write_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (60 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1588==
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 3003.285156 ms
# ==1588== Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (1 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (2 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1588==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (3 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (4 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (5 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (6 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (7 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (8 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (9 of 60)...
# 	elapsed_cycles_sm
# 	l2_subp0_read_l1_sector_queries
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (10 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (11 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (12 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (13 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (14 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (15 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (16 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (17 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (18 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (19 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (20 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (21 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (22 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (23 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (24 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (25 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (26 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (27 of 60)...
# 	l2_subp0_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (28 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (29 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (30 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (31 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (32 of 60)...
# 	l2_subp3_write_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (33 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (34 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (35 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (36 of 60)...
# 	rocache_gld_inst_8bit
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (37 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (38 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (39 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (40 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (41 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (42 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (44 of 60)...
# 	l2_subp1_write_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1588==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (45 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (46 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (47 of 60)...
# 	l2_subp2_write_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (48 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (49 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (50 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (51 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (52 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1588==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (53 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (54 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (55 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (56 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (57 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (58 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (59 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (60 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	active_cycles
# 	10 internal events
# ==1588==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 3475.456055 ms
# ==1588== Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (1 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (2 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (3 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1588==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (4 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (5 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (6 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (7 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (8 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (9 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (10 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (11 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (12 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (13 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (15 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (16 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (18 of 60)...
# 	l2_subp3_write_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (19 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (20 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (21 of 60)...
# 	l2_subp0_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (22 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (23 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (24 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (25 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (26 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (27 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (28 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (29 of 60)...
# 	rocache_gld_inst_8bit
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (30 of 60)...
# 	elapsed_cycles_sm
# 	l2_subp0_read_l1_sector_queries
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (31 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (32 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (33 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (34 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (35 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (36 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (37 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	active_cycles
# 	10 internal events
# ==1588==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (38 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (39 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (40 of 60)...
# 	l2_subp1_write_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1588==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (41 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (42 of 60)...
# 	l2_subp2_write_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (44 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (45 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (46 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (47 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (48 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (49 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (50 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (52 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (53 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (54 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (55 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1588==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (56 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (57 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (58 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (59 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (60 of 60)...
# 	4 internal events
# ==1588==
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 2991.373291 ms
# ==1588== Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (2 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (3 of 60)...
# 	l2_subp2_write_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (4 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (5 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	active_cycles
# 	10 internal events
# ==1588==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (6 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (7 of 60)...
# 	l2_subp3_write_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (8 of 60)...
# 	l2_subp0_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (9 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1588==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (10 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (11 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (12 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (13 of 60)...
# 	elapsed_cycles_sm
# 	l2_subp0_read_l1_sector_queries
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (15 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (16 of 60)...
# 	2 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (17 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (18 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (19 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (20 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (21 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (22 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (23 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (24 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (25 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (26 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (27 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (28 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (29 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (30 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (31 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (32 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1588==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (33 of 60)...
# 	l2_subp1_write_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1588==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (34 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (35 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (36 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (37 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (38 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (39 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (40 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (41 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (42 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (43 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (44 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (45 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1588==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (46 of 60)...
# 	1 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (47 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (48 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (49 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (50 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (51 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1588==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (52 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (53 of 60)...
# 	rocache_gld_inst_8bit
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (54 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (55 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (56 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (57 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (58 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1588==
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (59 of 60)...
# 	4 internal events
# ==1588==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (60 of 60)...
# 	1 internal events
# ==1588==
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 2830.479736 ms
# ==1588== Profiling application: /content/src/transpose 8192 8192
# ==1588== Profiling result:
# ==1588== Event result:
# Invocations                                Event Name         Min         Max         Avg       Total
# Device "Tesla K80 (0)"
#     Kernel: gpuTransposeCol(float*, float*, int, int)
#           1                            warps_launched     2097152     2097152     2097152     2097152
#           1                                local_load           0           0           0           0
#     Kernel: gpuTransposeCoalescedNoBC(float*, float*, int, int)
#           1                            warps_launched     2097152     2097152     2097152     2097152
#           1                                local_load           0           0           0           0
#     Kernel: gpuTransposeRow(float*, float*, int, int)
#           1                            warps_launched     2097152     2097152     2097152     2097152
#           1                                local_load           0           0           0           0
#     Kernel: gpuTransposeCoalesced(float*, float*, int, int)
#           1                            warps_launched     2097152     2097152     2097152     2097152
#           1                                local_load           0           0           0           0
#
# ==1588== Metric result:
# Invocations                               Metric Name                                    Metric Description         Min         Max         Avg
# Device "Tesla K80 (0)"
#     Kernel: gpuTransposeCol(float*, float*, int, int)
#           1                  l1_cache_global_hit_rate                                    L1 Global Hit Rate       0.00%       0.00%       0.00%
#           1                   l1_cache_local_hit_rate                                     L1 Local Hit Rate       0.00%       0.00%       0.00%
#           1                             sm_efficiency                               Multiprocessor Activity      99.94%      99.94%      99.94%
#           1                                       ipc                                          Executed IPC    0.264883    0.264883    0.264883
#           1                        achieved_occupancy                                    Achieved Occupancy    0.749209    0.749209    0.749209
#           1                  gld_requested_throughput                      Requested Global Load Throughput  11.510GB/s  11.510GB/s  11.510GB/s
#           1                  gst_requested_throughput                     Requested Global Store Throughput  11.510GB/s  11.510GB/s  11.510GB/s
#           1                    sm_efficiency_instance                               Multiprocessor Activity      99.94%      99.94%      99.94%
#           1                              ipc_instance                                          Executed IPC    0.264883    0.264883    0.264883
#           1                      inst_replay_overhead                           Instruction Replay Overhead    1.889160    1.889160    1.889160
#           1                    shared_replay_overhead                         Shared Memory Replay Overhead    0.000000    0.000000    0.000000
#           1                    global_replay_overhead                         Global Memory Replay Overhead    1.550000    1.550000    1.550000
#           1              global_cache_replay_overhead                   Global Memory Cache Replay Overhead    0.000000    0.000000    0.000000
#           1                        tex_cache_hit_rate                                Texture Cache Hit Rate       0.00%       0.00%       0.00%
#           1                      tex_cache_throughput                              Texture Cache Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                      dram_read_throughput                         Device Memory Read Throughput  20.156GB/s  20.156GB/s  20.156GB/s
#           1                     dram_write_throughput                        Device Memory Write Throughput  14.387GB/s  14.387GB/s  14.387GB/s
#           1                            gst_throughput                               Global Store Throughput  11.510GB/s  11.510GB/s  11.510GB/s
#           1                            gld_throughput                                Global Load Throughput  92.080GB/s  92.080GB/s  92.080GB/s
#           1                     local_replay_overhead                    Local Memory Cache Replay Overhead    0.000000    0.000000    0.000000
#           1                         shared_efficiency                              Shared Memory Efficiency       0.00%       0.00%       0.00%
#           1                            gld_efficiency                         Global Memory Load Efficiency      12.50%      12.50%      12.50%
#           1                            gst_efficiency                        Global Memory Store Efficiency     100.00%     100.00%     100.00%
#           1                       l2_l1_read_hit_rate                                L2 Hit Rate (L1 Reads)      87.50%      87.50%      87.50%
#           1                  l2_texture_read_hit_rate                           L2 Hit Rate (Texture Reads)       0.00%       0.00%       0.00%
#           1                     l2_l1_read_throughput                              L2 Throughput (L1 Reads)  92.080GB/s  92.080GB/s  92.080GB/s
#           1                l2_texture_read_throughput                         L2 Throughput (Texture Reads)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                     local_memory_overhead                                 Local Memory Overhead       0.00%       0.00%       0.00%
#           1                 warp_execution_efficiency                             Warp Execution Efficiency     100.00%     100.00%     100.00%
#           1               nc_gld_requested_throughput         Requested Non-Coherent Global Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                                issued_ipc                                            Issued IPC    0.765492    0.765492    0.765492
#           1                             inst_per_warp                                 Instructions per warp   20.000000   20.000000   20.000000
#           1                    issue_slot_utilization                                Issue Slot Utilization      18.05%      18.05%      18.05%
#           1       local_load_transactions_per_request            Local Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1      local_store_transactions_per_request           Local Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1      shared_load_transactions_per_request           Shared Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1     shared_store_transactions_per_request          Shared Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1              gld_transactions_per_request                  Global Load Transactions Per Request   32.000000   32.000000   32.000000
#           1              gst_transactions_per_request                 Global Store Transactions Per Request    1.000000    1.000000    1.000000
#           1                   local_load_transactions                               Local Load Transactions           0           0           0
#           1                  local_store_transactions                              Local Store Transactions           0           0           0
#           1                  shared_load_transactions                              Shared Load Transactions           0           0           0
#           1                 shared_store_transactions                             Shared Store Transactions           0           0           0
#           1                          gld_transactions                              Global Load Transactions    67108864    67108864    67108864
#           1                          gst_transactions                             Global Store Transactions     2097152     2097152     2097152
#           1                  sysmem_read_transactions                       System Memory Read Transactions           0           0           0
#           1                 sysmem_write_transactions                      System Memory Write Transactions           9           9           9
#           1                    tex_cache_transactions                            Texture Cache Transactions           0           0           0
#           1                    dram_read_transactions                       Device Memory Read Transactions    14690084    14690084    14690084
#           1                   dram_write_transactions                      Device Memory Write Transactions    10485772    10485772    10485772
#           1                      l2_read_transactions                                  L2 Read Transactions    67110040    67110040    67110040
#           1                     l2_write_transactions                                 L2 Write Transactions     8388621     8388621     8388621
#           1                     local_load_throughput                          Local Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    local_store_throughput                         Local Memory Store Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    shared_load_throughput                         Shared Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   shared_store_throughput                        Shared Memory Store Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                        l2_read_throughput                                 L2 Throughput (Reads)  92.081GB/s  92.081GB/s  92.081GB/s
#           1                       l2_write_throughput                                L2 Throughput (Writes)  11.510GB/s  11.510GB/s  11.510GB/s
#           1                    sysmem_read_throughput                         System Memory Read Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   sysmem_write_throughput                        System Memory Write Throughput  12.948KB/s  12.948KB/s  12.947KB/s
#           1         warp_nonpred_execution_efficiency              Warp Non-Predicated Execution Efficiency      95.00%      95.00%      95.00%
#           1                                 cf_issued                      Issued Control-Flow Instructions     4758355     4758355     4758355
# ...
#           1                      dram_read_throughput                         Device Memory Read Throughput  35.083GB/s  35.083GB/s  35.083GB/s
#           1                     dram_write_throughput                        Device Memory Write Throughput  35.613GB/s  35.613GB/s  35.613GB/s
#           1                            gst_throughput                               Global Store Throughput  28.490GB/s  28.490GB/s  28.490GB/s
#           1                            gld_throughput                                Global Load Throughput  28.490GB/s  28.490GB/s  28.490GB/s
#           1                     local_replay_overhead                    Local Memory Cache Replay Overhead    0.000000    0.000000    0.000000
#           1                         shared_efficiency                              Shared Memory Efficiency       5.88%       5.88%       5.88%
#           1                            gld_efficiency                         Global Memory Load Efficiency     100.00%     100.00%     100.00%
#           1                            gst_efficiency                        Global Memory Store Efficiency     100.00%     100.00%     100.00%
#           1                       l2_l1_read_hit_rate                                L2 Hit Rate (L1 Reads)       0.00%       0.00%       0.00%
#           1                  l2_texture_read_hit_rate                           L2 Hit Rate (Texture Reads)       0.00%       0.00%       0.00%
#           1                     l2_l1_read_throughput                              L2 Throughput (L1 Reads)  28.490GB/s  28.490GB/s  28.490GB/s
#           1                l2_texture_read_throughput                         L2 Throughput (Texture Reads)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                     local_memory_overhead                                 Local Memory Overhead       0.00%       0.00%       0.00%
#           1                 warp_execution_efficiency                             Warp Execution Efficiency     100.00%     100.00%     100.00%
#           1               nc_gld_requested_throughput         Requested Non-Coherent Global Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                                issued_ipc                                            Issued IPC    1.405878    1.405878    1.405878
#           1                             inst_per_warp                                 Instructions per warp   26.000000   26.000000   26.000000
#           1                    issue_slot_utilization                                Issue Slot Utilization      32.57%      32.57%      32.57%
#           1       local_load_transactions_per_request            Local Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1      local_store_transactions_per_request           Local Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1      shared_load_transactions_per_request           Shared Memory Load Transactions Per Request   16.000000   16.000000   16.000000
#           1     shared_store_transactions_per_request          Shared Memory Store Transactions Per Request    1.000000    1.000000    1.000000
#           1              gld_transactions_per_request                  Global Load Transactions Per Request    1.000000    1.000000    1.000000
#           1              gst_transactions_per_request                 Global Store Transactions Per Request    1.000000    1.000000    1.000000
#           1                   local_load_transactions                               Local Load Transactions           0           0           0
#           1                  local_store_transactions                              Local Store Transactions           0           0           0
#           1                  shared_load_transactions                              Shared Load Transactions    33554432    33554432    33554432
#           1                 shared_store_transactions                             Shared Store Transactions     2097153     2097153     2097153
#           1                          gld_transactions                              Global Load Transactions     2097152     2097152     2097152
#           1                          gst_transactions                             Global Store Transactions     2097152     2097152     2097152
#           1                  sysmem_read_transactions                       System Memory Read Transactions           0           0           0
#           1                 sysmem_write_transactions                      System Memory Write Transactions           5           5           5
#           1                    tex_cache_transactions                            Texture Cache Transactions           0           0           0
#           1                    dram_read_transactions                       Device Memory Read Transactions    10329745    10329745    10329745
#           1                   dram_write_transactions                      Device Memory Write Transactions    10485776    10485776    10485776
#           1                      l2_read_transactions                                  L2 Read Transactions     8389724     8389724     8389724
#           1                     l2_write_transactions                                 L2 Write Transactions     8388618     8388618     8388618
#           1                     local_load_throughput                          Local Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    local_store_throughput                         Local Memory Store Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    shared_load_throughput                         Shared Memory Load Throughput  911.69GB/s  911.69GB/s  911.69GB/s
#           1                   shared_store_throughput                        Shared Memory Store Throughput  56.980GB/s  56.980GB/s  56.980GB/s
#           1                        l2_read_throughput                                 L2 Throughput (Reads)  28.494GB/s  28.494GB/s  28.494GB/s
#           1                       l2_write_throughput                                L2 Throughput (Writes)  28.490GB/s  28.490GB/s  28.490GB/s
#           1                    sysmem_read_throughput                         System Memory Read Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   sysmem_write_throughput                        System Memory Write Throughput  17.806KB/s  17.806KB/s  17.805KB/s
#           1         warp_nonpred_execution_efficiency              Warp Non-Predicated Execution Efficiency     100.00%     100.00%     100.00%
#           1                                 cf_issued                      Issued Control-Flow Instructions     4508664     4508664     4508664
#           1                               cf_executed                    Executed Control-Flow Instructions     4194304     4194304     4194304
#           1                               ldst_issued                        Issued Load/Store Instructions    41470339    41470339    41470339
#           1                             ldst_executed                      Executed Load/Store Instructions     8388608     8388608     8388608
#           1                             flop_count_sp           Floating Point Operations(Single Precision)           0           0           0
#           1                         flop_count_sp_add       Floating Point Operations(Single Precision Add)           0           0           0
#           1                         flop_count_sp_mul        Floating Point Operation(Single Precision Mul)           0           0           0
#           1                         flop_count_sp_fma       Floating Point Operations(Single Precision FMA)           0           0           0
#           1                             flop_count_dp           Floating Point Operations(Double Precision)           0           0           0
#           1                         flop_count_dp_add       Floating Point Operations(Double Precision Add)           0           0           0
#           1                         flop_count_dp_mul       Floating Point Operations(Double Precision Mul)           0           0           0
#           1                         flop_count_dp_fma       Floating Point Operations(Double Precision FMA)           0           0           0
#           1                     flop_count_sp_special   Floating Point Operations(Single Precision Special)           0           0           0
#           1                          stall_inst_fetch              Issue Stall Reasons (Instructions Fetch)       1.51%       1.51%       1.51%
#           1                     stall_exec_dependency            Issue Stall Reasons (Execution Dependency)      12.12%      12.12%      12.12%
#           1                   stall_memory_dependency                    Issue Stall Reasons (Data Request)       6.58%       6.58%       6.58%
#           1                             stall_texture                         Issue Stall Reasons (Texture)       0.00%       0.00%       0.00%
#           1                                stall_sync                 Issue Stall Reasons (Synchronization)       9.03%       9.03%       9.03%
#           1                               stall_other                           Issue Stall Reasons (Other)       2.18%       2.18%       2.18%
#           1                     l1_shared_utilization                          L1/Shared Memory Utilization     Mid (6)     Mid (6)     Mid (6)
#           1                            l2_utilization                                  L2 Cache Utilization     Low (1)     Low (1)     Low (1)
#           1                           tex_utilization                             Texture Cache Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                          dram_utilization                             Device Memory Utilization     Mid (4)     Mid (4)     Mid (4)
#           1                        sysmem_utilization                             System Memory Utilization     Low (1)     Low (1)     Low (1)
#           1                       ldst_fu_utilization                  Load/Store Function Unit Utilization    High (7)    High (7)    High (7)
#           1                        alu_fu_utilization                  Arithmetic Function Unit Utilization     Mid (4)     Mid (4)     Mid (4)
#           1                         cf_fu_utilization                Control-Flow Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                        tex_fu_utilization                     Texture Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                             inst_executed                                 Instructions Executed    54525952    54525952    54525952
#           1                               inst_issued                                   Instructions Issued    90023720    90023720    90023720
#           1                               issue_slots                                           Issue Slots    83418325    83418325    83418325
#           1                     nc_l2_read_throughput                    L2 Throughput (Non-Coherent Reads)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   nc_l2_read_transactions                     L2 Non-Coherent Read Transactions           0           0           0
#           1                  nc_cache_global_hit_rate                          Non-Coherent Global Hit Rate       0.00%       0.00%       0.00%
#           1                         nc_gld_throughput            Non-Coherent Global Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                         nc_gld_efficiency                   Non-Coherent Global Load Efficiency       0.00%       0.00%       0.00%
#           1                      l2_atomic_throughput                       L2 Throughput (Atomic requests)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                                inst_fp_32                               FP Instructions(Single)           0           0           0
#           1                                inst_fp_64                               FP Instructions(Double)           0           0           0
#           1                              inst_integer                                  Integer Instructions   939524096   939524096   939524096
#           1                          inst_bit_convert                              Bit-Convert Instructions           0           0           0
#           1                              inst_control                             Control-Flow Instructions    67108864    67108864    67108864
#           1                        inst_compute_ld_st                               Load/Store Instructions   268435456   268435456   268435456
#           1                                 inst_misc                                     Misc Instructions   469762048   469762048   469762048
#           1           inst_inter_thread_communication                             Inter-Thread Instructions           0           0           0
#           1                    atomic_replay_overhead                                Atomic Replay Overhead    0.000000    0.000000    0.000000
#           1                       atomic_transactions                                   Atomic Transactions           0           0           0
#           1           atomic_transactions_per_request                       Atomic Transactions Per Request    0.000000    0.000000    0.000000
#           1                   sysmem_read_utilization                        System Memory Read Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                  sysmem_write_utilization                       System Memory Write Utilization     Low (1)     Low (1)     Low (1)
#           1                   l2_l1_read_transactions               L2 Read Transactions (L1 read requests)     8388608     8388608     8388608
#           1                  l2_l1_write_transactions             L2 Write Transactions (L1 write requests)     8388608     8388608     8388608
#           1                  l2_tex_read_transactions                       L2 Transactions (Texture Reads)           0           0           0
#           1                    l2_l1_write_throughput                             L2 Throughput (L1 Writes)  28.490GB/s  28.490GB/s  28.490GB/s
#           1                    l2_atomic_transactions                     L2 Transactions (Atomic requests)           0           0           0
#           1                          ecc_transactions                                      ECC Transactions     4038279     4038279     4038279
#           1                            ecc_throughput                                        ECC Throughput  13.715GB/s  13.715GB/s  13.715GB/s
#           1                           stall_pipe_busy                       Issue Stall Reasons (Pipe Busy)      35.00%      35.00%      35.00%
#           1          stall_constant_memory_dependency              Issue Stall Reasons (Immediate constant)       0.01%       0.01%       0.01%
#           1                        flop_sp_efficiency                          FLOP Efficiency(Peak Single)       0.00%       0.00%       0.00%
#           1                        flop_dp_efficiency                          FLOP Efficiency(Peak Double)       0.00%       0.00%       0.00%
#           1                     stall_memory_throttle                 Issue Stall Reasons (Memory Throttle)      19.79%      19.79%      19.79%
#           1                        stall_not_selected                    Issue Stall Reasons (Not Selected)      13.78%      13.78%      13.78%
#           1                  eligible_warps_per_cycle                       Eligible Warps Per Active Cycle    8.251234    8.251234    8.251234
#           1                         atomic_throughput                                     Atomic Throughput  0.00000B/s  0.00000B/s  0.00000B/s

# %%
# !nvprof --events warps_launched,local_load --metrics all /content/src/transpose 4096 4096 # when in transpose col x, y are interchanged
# Out:
# ==266== NVPROF is profiling process 266, command: /content/src/transpose 4096 4096
# +++ m = 4096 n = 4096, CPU Time taken = 427.366000 ms
# grid dim = 128
# ==266== Some kernel(s) will be replayed on device 0 in order to collect all events/metrics.
# ==266== Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (1 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (2 of 60)...
# 	warps_launched
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (3 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (4 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp1_read_sectors
# 	fb1_subp1_read_sectors
# 	fb_subp1_write_sectors
# 	fb1_subp1_write_sectors
# 	inst_executed
# 	not_predicated_off_thread_inst_executed
# 	inst_issued1
# 	inst_issued2
# 	l2_subp0_write_sysmem_sector_queries
# 	l2_subp1_write_sysmem_sector_queries
# 	4 internal events
# ==266==
#
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (5 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (6 of 60)...
# 	1 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (7 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp0_read_sectors
# 	fb1_subp0_read_sectors
# 	fb_subp0_write_sectors
# 	fb1_subp0_write_sectors
# 	inst_executed
# 	branch
# 	divergent_branch
# 	thread_inst_executed
# 	6 internal events
# ==266==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (8 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (9 of 60)...
# 	elapsed_cycles_pm
# 	global_atom_cas
# 	atom_count
# 	l2_subp0_read_tex_hit_sectors
# 	l2_subp1_read_tex_hit_sectors
# 	6 internal events
# ==266==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (10 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (11 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (12 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (13 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (15 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (16 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (17 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (18 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (19 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (20 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (21 of 60)...
# 	global_load
# 	l2_subp0_write_tex_hit_sectors
# 	l2_subp1_write_tex_hit_sectors
# 	7 internal events
# ==266==
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (22 of 60)...
# 	active_cycles
# 	4 internal events
# ==266==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (23 of 60)...
# 	10 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (24 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (25 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (26 of 60)...
# 	5 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (27 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (28 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (29 of 60)...
# 	elapsed_cycles_pm
# 	inst_executed_shared_atom_cas
# 	shared_atom
# 	shared_load
# 	shared_store
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==266==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (30 of 60)...
# 	active_cycles
# 	4 internal events
# ==266==
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (31 of 60)...
# 	elapsed_cycles_pm
# 	global_store
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	5 internal events
# ==266==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (33 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (34 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (35 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (36 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (37 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (38 of 60)...
# 	active_cycles
# 	elapsed_cycles_sm
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	active_warps
# 	shared_ld_transactions
# 	shared_st_transactions
# ==266==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (39 of 60)...
# 	1 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (41 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (42 of 60)...
# 	elapsed_cycles_pm
# 	local_store
# 	l2_subp0_total_write_sector_queries
# 	l2_subp1_total_write_sector_queries
# 	5 internal events
# ==266==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (43 of 60)...
# 	8 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (44 of 60)...
# 	elapsed_cycles_pm
# 	local_load
# 	l2_subp0_total_read_sector_queries
# 	l2_subp1_total_read_sector_queries
# 	7 internal events
# ==266==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (45 of 60)...
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	7 internal events
# ==266==
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (46 of 60)...
# 	gred_count
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	5 internal events
# ==266==
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (47 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (48 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (49 of 60)...
# 	active_cycles
# 	inst_issued1
# 	inst_issued2
# 	2 internal events
# ==266==
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (50 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (52 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (53 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (54 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (56 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (57 of 60)...
# 	tex0_cache_sector_queries
# 	tex1_cache_sector_queries
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==266==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (58 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (59 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (60 of 60)...
# 	2 internal events
# ==266==
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (done)
# +++ m = 4096 n = 4096, GPU Transpose (Read Rows, Store Cols) Time taken = 1121.667969 ms
# ==266== Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (1 of 60)...
# 	active_cycles
# 	4 internal events
# ==266==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (2 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (3 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (4 of 60)...
# 	1 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (5 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (6 of 60)...
# 	1 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (7 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (8 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (9 of 60)...
# 	active_cycles
# 	4 internal events
# ==266==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (10 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (11 of 60)...
# 	8 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (12 of 60)...
# 	warps_launched
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (13 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp0_read_sectors
# 	fb1_subp0_read_sectors
# 	fb_subp0_write_sectors
# 	fb1_subp0_write_sectors
# 	inst_executed
# 	branch
# 	divergent_branch
# 	thread_inst_executed
# 	6 internal events
# ==266==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (14 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (15 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (16 of 60)...
# 	global_load
# 	l2_subp0_write_tex_hit_sectors
# 	l2_subp1_write_tex_hit_sectors
# 	7 internal events
# ==266==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (17 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (18 of 60)...
# 	elapsed_cycles_pm
# 	global_atom_cas
# 	atom_count
# 	l2_subp0_read_tex_hit_sectors
# 	l2_subp1_read_tex_hit_sectors
# 	6 internal events
# ==266==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (19 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (20 of 60)...
# 	elapsed_cycles_pm
# 	fb_subp1_read_sectors
# 	fb1_subp1_read_sectors
# 	fb_subp1_write_sectors
# 	fb1_subp1_write_sectors
# 	inst_executed
# 	not_predicated_off_thread_inst_executed
# 	inst_issued1
# 	inst_issued2
# 	l2_subp0_write_sysmem_sector_queries
# 	l2_subp1_write_sysmem_sector_queries
# 	4 internal events
# ==266==
#
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (21 of 60)...
# 	tex0_cache_sector_queries
# 	tex1_cache_sector_queries
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==266==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (22 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (23 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (24 of 60)...
# 	elapsed_cycles_pm
# 	global_store
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	5 internal events
# ==266==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (25 of 60)...
# 	5 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (26 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (27 of 60)...
# 	elapsed_cycles_pm
# 	local_store
# 	l2_subp0_total_write_sector_queries
# 	l2_subp1_total_write_sector_queries
# 	5 internal events
# ==266==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (28 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (29 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (30 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (31 of 60)...
# 	active_cycles
# 	elapsed_cycles_sm
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	active_warps
# 	shared_ld_transactions
# 	shared_st_transactions
# ==266==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (33 of 60)...
# 	10 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (34 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (35 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (36 of 60)...
# 	active_cycles
# 	inst_issued1
# 	inst_issued2
# 	2 internal events
# ==266==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (37 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (38 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (39 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (41 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (42 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (43 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (44 of 60)...
# 	gred_count
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	5 internal events
# ==266==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (45 of 60)...
# 	elapsed_cycles_pm
# 	inst_executed_shared_atom_cas
# 	shared_atom
# 	shared_load
# 	shared_store
# 	l2_subp0_read_tex_sector_queries
# 	l2_subp1_read_tex_sector_queries
# 	4 internal events
# ==266==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (46 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (47 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (48 of 60)...
# 	l2_subp0_write_tex_sector_queries
# 	l2_subp1_write_tex_sector_queries
# 	7 internal events
# ==266==
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (49 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (50 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (52 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (53 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (54 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (56 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (57 of 60)...
# 	2 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (58 of 60)...
# 	elapsed_cycles_pm
# 	local_load
# 	l2_subp0_total_read_sector_queries
# 	l2_subp1_total_read_sector_queries
# 	7 internal events
# ==266==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (59 of 60)...
# 	4 internal events
# ==266==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (60 of 60)...
# 	4 internal events
# ==266==
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (done)
# +++ m = 4096 n = 4096, GPU Transpose (Read Cols, Store Rows) Time taken = 1023.412537 ms
# ==266== Profiling application: /content/src/transpose 4096 4096
# ==266== Profiling result:
# ==266== Event result:
# Invocations                                Event Name         Min         Max         Avg       Total
# Device "Tesla P100-PCIE-16GB (0)"
#     Kernel: gpuTransposeCol(float*, float*, int, int)
#           1                            warps_launched      524288      524288      524288      524288
#           1                                local_load           0           0           0           0
#     Kernel: gpuTransposeRow(float*, float*, int, int)
#           1                            warps_launched      524288      524288      524288      524288
#           1                                local_load           0           0           0           0
#
# ==266== Metric result:
# Invocations                               Metric Name                                                    Metric Description         Min         Max         Avg
# Device "Tesla P100-PCIE-16GB (0)"
#     Kernel: gpuTransposeCol(float*, float*, int, int)
#           1                             inst_per_warp                                                 Instructions per warp   30.000000   30.000000   30.000000
#           1                         branch_efficiency                                                     Branch Efficiency     100.00%     100.00%     100.00%
#           1                 warp_execution_efficiency                                             Warp Execution Efficiency     100.00%     100.00%     100.00%
#           1         warp_nonpred_execution_efficiency                              Warp Non-Predicated Execution Efficiency      96.67%      96.67%      96.67%
#           1                      inst_replay_overhead                                           Instruction Replay Overhead    0.000750    0.000750    0.000750
#           1      shared_load_transactions_per_request                           Shared Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1     shared_store_transactions_per_request                          Shared Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1       local_load_transactions_per_request                            Local Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1      local_store_transactions_per_request                           Local Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1              gld_transactions_per_request                                  Global Load Transactions Per Request   16.000004   16.000004   16.000004
#           1              gst_transactions_per_request                                 Global Store Transactions Per Request    4.000000    4.000000    4.000000
#           1                 shared_store_transactions                                             Shared Store Transactions           0           0           0
#           1                  shared_load_transactions                                              Shared Load Transactions           0           0           0
#           1                   local_load_transactions                                               Local Load Transactions           0           0           0
#           1                  local_store_transactions                                              Local Store Transactions           0           0           0
#           1                          gld_transactions                                              Global Load Transactions     8388610     8388610     8388610
#           1                          gst_transactions                                             Global Store Transactions     2097152     2097152     2097152
#           1                  sysmem_read_transactions                                       System Memory Read Transactions           0           0           0
#           1                 sysmem_write_transactions                                      System Memory Write Transactions           5           5           5
#           1                      l2_read_transactions                                                  L2 Read Transactions     2097464     2097464     2097464
#           1                     l2_write_transactions                                                 L2 Write Transactions     2097172     2097172     2097172
#           1                    dram_read_transactions                                       Device Memory Read Transactions     2097180     2097180     2097180
#           1                   dram_write_transactions                                      Device Memory Write Transactions     2096400     2096400     2096400
#           1                           global_hit_rate                                     Global Hit Rate in unified l1/tex      87.50%      87.50%      87.50%
#           1                            local_hit_rate                                                        Local Hit Rate       0.00%       0.00%       0.00%
#           1                  gld_requested_throughput                                      Requested Global Load Throughput  194.74GB/s  194.74GB/s  194.74GB/s
#           1                  gst_requested_throughput                                     Requested Global Store Throughput  194.74GB/s  194.74GB/s  194.74GB/s
#           1                            gld_throughput                                                Global Load Throughput  1557.9GB/s  1557.9GB/s  1557.9GB/s
#           1                            gst_throughput                                               Global Store Throughput  194.74GB/s  194.74GB/s  194.74GB/s
#           1                     local_memory_overhead                                                 Local Memory Overhead       0.00%       0.00%       0.00%
#           1                        tex_cache_hit_rate                                                Unified Cache Hit Rate      80.00%      80.00%      80.00%
#           1                      l2_tex_read_hit_rate                                           L2 Hit Rate (Texture Reads)       0.00%       0.00%       0.00%
#           1                     l2_tex_write_hit_rate                                          L2 Hit Rate (Texture Writes)       0.00%       0.00%       0.00%
#           1                      dram_read_throughput                                         Device Memory Read Throughput  194.74GB/s  194.74GB/s  194.74GB/s
#           1                     dram_write_throughput                                        Device Memory Write Throughput  194.67GB/s  194.67GB/s  194.67GB/s
#           1                      tex_cache_throughput                                              Unified Cache Throughput  194.74GB/s  194.74GB/s  194.74GB/s
#           1                    l2_tex_read_throughput                                         L2 Throughput (Texture Reads)  194.74GB/s  194.74GB/s  194.74GB/s
#           1                   l2_tex_write_throughput                                        L2 Throughput (Texture Writes)  194.74GB/s  194.74GB/s  194.74GB/s
#           1                        l2_read_throughput                                                 L2 Throughput (Reads)  194.77GB/s  194.77GB/s  194.77GB/s
#           1                       l2_write_throughput                                                L2 Throughput (Writes)  194.74GB/s  194.74GB/s  194.74GB/s
#           1                    sysmem_read_throughput                                         System Memory Read Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   sysmem_write_throughput                                        System Memory Write Throughput  486.84KB/s  486.84KB/s  486.84KB/s
#           1                     local_load_throughput                                          Local Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    local_store_throughput                                         Local Memory Store Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    shared_load_throughput                                         Shared Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   shared_store_throughput                                        Shared Memory Store Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                            gld_efficiency                                         Global Memory Load Efficiency      12.50%      12.50%      12.50%
#           1                            gst_efficiency                                        Global Memory Store Efficiency     100.00%     100.00%     100.00%
#           1                    tex_cache_transactions                                            Unified Cache Transactions     2097152     2097152     2097152
#           1                             flop_count_dp                           Floating Point Operations(Double Precision)           0           0           0
#           1                         flop_count_dp_add                       Floating Point Operations(Double Precision Add)           0           0           0
#           1                         flop_count_dp_fma                       Floating Point Operations(Double Precision FMA)           0           0           0
#           1                         flop_count_dp_mul                       Floating Point Operations(Double Precision Mul)           0           0           0
#           1                             flop_count_sp                           Floating Point Operations(Single Precision)           0           0           0
#           1                         flop_count_sp_add                       Floating Point Operations(Single Precision Add)           0           0           0
#           1                         flop_count_sp_fma                       Floating Point Operations(Single Precision FMA)           0           0           0
#           1                         flop_count_sp_mul                        Floating Point Operation(Single Precision Mul)           0           0           0
#           1                     flop_count_sp_special                   Floating Point Operations(Single Precision Special)           0           0           0
#           1                             inst_executed                                                 Instructions Executed    15728640    15728640    15728640
#           1                               inst_issued                                                   Instructions Issued    15740438    15740438    15740438
#           1                          dram_utilization                                             Device Memory Utilization     Mid (6)     Mid (6)     Mid (6)
#           1                        sysmem_utilization                                             System Memory Utilization     Low (1)     Low (1)     Low (1)
#           1                          stall_inst_fetch                              Issue Stall Reasons (Instructions Fetch)       1.55%       1.55%       1.55%
#           1                     stall_exec_dependency                            Issue Stall Reasons (Execution Dependency)       5.98%       5.98%       5.98%
#           1                   stall_memory_dependency                                    Issue Stall Reasons (Data Request)      76.08%      76.08%      76.08%
#           1                             stall_texture                                         Issue Stall Reasons (Texture)       0.00%       0.00%       0.00%
#           1                                stall_sync                                 Issue Stall Reasons (Synchronization)       0.00%       0.00%       0.00%
#           1                               stall_other                                           Issue Stall Reasons (Other)      12.61%      12.61%      12.61%
#           1          stall_constant_memory_dependency                              Issue Stall Reasons (Immediate constant)       0.12%       0.12%       0.12%
#           1                           stall_pipe_busy                                       Issue Stall Reasons (Pipe Busy)       0.43%       0.43%       0.43%
#           1                         shared_efficiency                                              Shared Memory Efficiency       0.00%       0.00%       0.00%
#           1                                inst_fp_32                                               FP Instructions(Single)           0           0           0
#           1                                inst_fp_64                                               FP Instructions(Double)           0           0           0
#           1                              inst_integer                                                  Integer Instructions   335544320   335544320   335544320
#           1                          inst_bit_convert                                              Bit-Convert Instructions           0           0           0
#           1                              inst_control                                             Control-Flow Instructions    16777216    16777216    16777216
#           1                        inst_compute_ld_st                                               Load/Store Instructions    33554432    33554432    33554432
#           1                                 inst_misc                                                     Misc Instructions   100663296   100663296   100663296
#           1           inst_inter_thread_communication                                             Inter-Thread Instructions           0           0           0
#           1                               issue_slots                                                           Issue Slots    15740438    15740438    15740438
#           1                                 cf_issued                                      Issued Control-Flow Instructions     1048576     1048576     1048576
#           1                               cf_executed                                    Executed Control-Flow Instructions     1048576     1048576     1048576
#           1                               ldst_issued                                        Issued Load/Store Instructions     6291456     6291456     6291456
#           1                             ldst_executed                                      Executed Load/Store Instructions     3145728     3145728     3145728
#           1                       atomic_transactions                                                   Atomic Transactions           0           0           0
#           1           atomic_transactions_per_request                                       Atomic Transactions Per Request    0.000000    0.000000    0.000000
#           1                      l2_atomic_throughput                                       L2 Throughput (Atomic requests)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    l2_atomic_transactions                                     L2 Transactions (Atomic requests)           0           0           0
#           1                  l2_tex_read_transactions                                       L2 Transactions (Texture Reads)     2097152     2097152     2097152
#           1                     stall_memory_throttle                                 Issue Stall Reasons (Memory Throttle)       1.40%       1.40%       1.40%
#           1                        stall_not_selected                                    Issue Stall Reasons (Not Selected)       1.84%       1.84%       1.84%
#           1                 l2_tex_write_transactions                                      L2 Transactions (Texture Writes)     2097152     2097152     2097152
#           1                             flop_count_hp                             Floating Point Operations(Half Precision)           0           0           0
#           1                         flop_count_hp_add                         Floating Point Operations(Half Precision Add)           0           0           0
#           1                         flop_count_hp_mul                          Floating Point Operation(Half Precision Mul)           0           0           0
#           1                         flop_count_hp_fma                         Floating Point Operations(Half Precision FMA)           0           0           0
#           1                                inst_fp_16                                                 HP Instructions(Half)           0           0           0
#           1                                       ipc                                                          Executed IPC    0.737403    0.737403    0.737403
#           1                                issued_ipc                                                            Issued IPC    0.737829    0.737829    0.737829
#           1                    issue_slot_utilization                                                Issue Slot Utilization      36.89%      36.89%      36.89%
#           1                             sm_efficiency                                               Multiprocessor Activity      98.50%      98.50%      98.50%
#           1                        achieved_occupancy                                                    Achieved Occupancy    0.716977    0.716977    0.716977
#           1                  eligible_warps_per_cycle                                       Eligible Warps Per Active Cycle    1.574561    1.574561    1.574561
#           1                        shared_utilization                                             Shared Memory Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                            l2_utilization                                                  L2 Cache Utilization     Low (2)     Low (2)     Low (2)
#           1                           tex_utilization                                             Unified Cache Utilization     Low (1)     Low (1)     Low (1)
#           1                       ldst_fu_utilization                                  Load/Store Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                         cf_fu_utilization                                Control-Flow Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                        tex_fu_utilization                                     Texture Function Unit Utilization     Low (2)     Low (2)     Low (2)
#           1                    special_fu_utilization                                     Special Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1             half_precision_fu_utilization                              Half-Precision Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1           single_precision_fu_utilization                            Single-Precision Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1           double_precision_fu_utilization                            Double-Precision Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                        flop_hp_efficiency                                            FLOP Efficiency(Peak Half)       0.00%       0.00%       0.00%
#           1                        flop_sp_efficiency                                          FLOP Efficiency(Peak Single)       0.00%       0.00%       0.00%
#           1                        flop_dp_efficiency                                          FLOP Efficiency(Peak Double)       0.00%       0.00%       0.00%
#           1                   sysmem_read_utilization                                        System Memory Read Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                  sysmem_write_utilization                                       System Memory Write Utilization     Low (1)     Low (1)     Low (1)
#           1               pcie_total_data_transmitted                                           PCIe Total Data Transmitted           0           0           0
#           1                  pcie_total_data_received                                              PCIe Total Data Received           0           0           0
#           1                inst_executed_global_loads                              Warp level instructions for global loads      524288      524288      524288
#           1                 inst_executed_local_loads                               Warp level instructions for local loads           0           0           0
#           1                inst_executed_shared_loads                              Warp level instructions for shared loads           0           0           0
#           1               inst_executed_surface_loads                             Warp level instructions for surface loads           0           0           0
#           1               inst_executed_global_stores                             Warp level instructions for global stores      524288      524288      524288
#           1                inst_executed_local_stores                              Warp level instructions for local stores           0           0           0
#           1               inst_executed_shared_stores                             Warp level instructions for shared stores           0           0           0
#           1              inst_executed_surface_stores                            Warp level instructions for surface stores           0           0           0
#           1              inst_executed_global_atomics                  Warp level instructions for global atom and atom cas           0           0           0
#           1           inst_executed_global_reductions                         Warp level instructions for global reductions           0           0           0
#           1             inst_executed_surface_atomics                 Warp level instructions for surface atom and atom cas           0           0           0
#           1          inst_executed_surface_reductions                        Warp level instructions for surface reductions           0           0           0
#           1              inst_executed_shared_atomics                  Warp level shared instructions for atom and atom CAS           0           0           0
#           1                     inst_executed_tex_ops                                   Warp level instructions for texture           0           0           0
#           1                      l2_global_load_bytes       Bytes read from L2 for misses in Unified Cache for global loads    67108864    67108864    67108864
#           1                       l2_local_load_bytes        Bytes read from L2 for misses in Unified Cache for local loads           0           0           0
#           1                     l2_surface_load_bytes      Bytes read from L2 for misses in Unified Cache for surface loads           0           0           0
#           1                           dram_read_bytes                                Total bytes read from DRAM to L2 cache    67109760    67109760    67109760
#           1                          dram_write_bytes                             Total bytes written from L2 cache to DRAM    67084800    67084800    67084800
#           1               l2_local_global_store_bytes   Bytes written to L2 from Unified Cache for local and global stores.    67108864    67108864    67108864
#           1                 l2_global_reduction_bytes          Bytes written to L2 from Unified cache for global reductions           0           0           0
#           1              l2_global_atomic_store_bytes             Bytes written to L2 from Unified cache for global atomics           0           0           0
#           1                    l2_surface_store_bytes            Bytes written to L2 from Unified Cache for surface stores.           0           0           0
#           1                l2_surface_reduction_bytes         Bytes written to L2 from Unified Cache for surface reductions           0           0           0
#           1             l2_surface_atomic_store_bytes    Bytes transferred between Unified Cache and L2 for surface atomics           0           0           0
#           1                      global_load_requests              Total number of global load requests from Multiprocessor     2097152     2097152     2097152
#           1                       local_load_requests               Total number of local load requests from Multiprocessor           0           0           0
#           1                     surface_load_requests             Total number of surface load requests from Multiprocessor           0           0           0
#           1                     global_store_requests             Total number of global store requests from Multiprocessor     2097152     2097152     2097152
#           1                      local_store_requests              Total number of local store requests from Multiprocessor           0           0           0
#           1                    surface_store_requests            Total number of surface store requests from Multiprocessor           0           0           0
#           1                    global_atomic_requests            Total number of global atomic requests from Multiprocessor           0           0           0
#           1                 global_reduction_requests         Total number of global reduction requests from Multiprocessor           0           0           0
#           1                   surface_atomic_requests           Total number of surface atomic requests from Multiprocessor           0           0           0
#           1                surface_reduction_requests        Total number of surface reduction requests from Multiprocessor           0           0           0
#           1                         sysmem_read_bytes                                              System Memory Read Bytes           0           0           0
#           1                        sysmem_write_bytes                                             System Memory Write Bytes         160         160         160
#           1                           l2_tex_hit_rate                                                     L2 Cache Hit Rate       0.00%       0.00%       0.00%
#           1                     texture_load_requests             Total number of texture Load requests from Multiprocessor           0           0           0
#           1                     unique_warps_launched                                              Number of warps launched      524288      524288      524288
#     Kernel: gpuTransposeRow(float*, float*, int, int)
#           1                             inst_per_warp                                                 Instructions per warp   30.000000   30.000000   30.000000
#           1                         branch_efficiency                                                     Branch Efficiency     100.00%     100.00%     100.00%
#           1                 warp_execution_efficiency                                             Warp Execution Efficiency     100.00%     100.00%     100.00%
#           1         warp_nonpred_execution_efficiency                              Warp Non-Predicated Execution Efficiency      96.67%      96.67%      96.67%
#           1                      inst_replay_overhead                                           Instruction Replay Overhead    0.000710    0.000710    0.000710
#           1      shared_load_transactions_per_request                           Shared Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1     shared_store_transactions_per_request                          Shared Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1       local_load_transactions_per_request                            Local Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1      local_store_transactions_per_request                           Local Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1              gld_transactions_per_request                                  Global Load Transactions Per Request   16.000004   16.000004   16.000004
#           1              gst_transactions_per_request                                 Global Store Transactions Per Request   32.000000   32.000000   32.000000
#           1                 shared_store_transactions                                             Shared Store Transactions           0           0           0
#           1                  shared_load_transactions                                              Shared Load Transactions           0           0           0
#           1                   local_load_transactions                                               Local Load Transactions           0           0           0
#           1                  local_store_transactions                                              Local Store Transactions           0           0           0
#           1                          gld_transactions                                              Global Load Transactions     8388610     8388610     8388610
#           1                          gst_transactions                                             Global Store Transactions    16777216    16777216    16777216
#           1                  sysmem_read_transactions                                       System Memory Read Transactions           0           0           0
#           1                 sysmem_write_transactions                                      System Memory Write Transactions           5           5           5
#           1                      l2_read_transactions                                                  L2 Read Transactions     2097248     2097248     2097248
#           1                     l2_write_transactions                                                 L2 Write Transactions    17082168    17082168    17082168
#           1                    dram_read_transactions                                       Device Memory Read Transactions     2371182     2371182     2371182
#           1                   dram_write_transactions                                      Device Memory Write Transactions     2378695     2378695     2378695
#           1                           global_hit_rate                                     Global Hit Rate in unified l1/tex       0.00%       0.00%       0.00%
#           1                            local_hit_rate                                                        Local Hit Rate       0.00%       0.00%       0.00%
#           1                  gld_requested_throughput                                      Requested Global Load Throughput  57.590GB/s  57.590GB/s  57.590GB/s
#           1                  gst_requested_throughput                                     Requested Global Store Throughput  57.590GB/s  57.590GB/s  57.590GB/s
#           1                            gld_throughput                                                Global Load Throughput  57.590GB/s  57.590GB/s  57.590GB/s
#           1                            gst_throughput                                               Global Store Throughput  460.72GB/s  460.72GB/s  460.72GB/s
# ...
#           1                          dram_utilization                                             Device Memory Utilization     Low (2)     Low (2)     Low (2)
#           1                        sysmem_utilization                                             System Memory Utilization     Low (1)     Low (1)     Low (1)
#           1                          stall_inst_fetch                              Issue Stall Reasons (Instructions Fetch)       0.47%       0.47%       0.47%
#           1                     stall_exec_dependency                            Issue Stall Reasons (Execution Dependency)       1.79%       1.79%       1.79%
#           1                   stall_memory_dependency                                    Issue Stall Reasons (Data Request)      58.30%      58.30%      58.30%
#           1                             stall_texture                                         Issue Stall Reasons (Texture)       0.12%       0.12%       0.12%
#           1                                stall_sync                                 Issue Stall Reasons (Synchronization)       0.00%       0.00%       0.00%
#           1                               stall_other                                           Issue Stall Reasons (Other)       3.75%       3.75%       3.75%
#           1          stall_constant_memory_dependency                              Issue Stall Reasons (Immediate constant)       0.04%       0.04%       0.04%
#           1                           stall_pipe_busy                                       Issue Stall Reasons (Pipe Busy)       0.13%       0.13%       0.13%
#           1                         shared_efficiency                                              Shared Memory Efficiency       0.00%       0.00%       0.00%
#           1                                inst_fp_32                                               FP Instructions(Single)           0           0           0
#           1                                inst_fp_64                                               FP Instructions(Double)           0           0           0
#           1                              inst_integer                                                  Integer Instructions   335544320   335544320   335544320
#           1                          inst_bit_convert                                              Bit-Convert Instructions           0           0           0
#           1                              inst_control                                             Control-Flow Instructions    16777216    16777216    16777216
#           1                        inst_compute_ld_st                                               Load/Store Instructions    33554432    33554432    33554432
#           1                                 inst_misc                                                     Misc Instructions   100663296   100663296   100663296
#           1           inst_inter_thread_communication                                             Inter-Thread Instructions           0           0           0
#           1                               issue_slots                                                           Issue Slots    15739803    15739803    15739803
#           1                                 cf_issued                                      Issued Control-Flow Instructions     1048576     1048576     1048576
#           1                               cf_executed                                    Executed Control-Flow Instructions     1048576     1048576     1048576
#           1                               ldst_issued                                        Issued Load/Store Instructions     6291456     6291456     6291456
#           1                             ldst_executed                                      Executed Load/Store Instructions     3145728     3145728     3145728
#           1                       atomic_transactions                                                   Atomic Transactions           0           0           0
#           1           atomic_transactions_per_request                                       Atomic Transactions Per Request    0.000000    0.000000    0.000000
#           1                      l2_atomic_throughput                                       L2 Throughput (Atomic requests)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    l2_atomic_transactions                                     L2 Transactions (Atomic requests)           0           0           0
#           1                  l2_tex_read_transactions                                       L2 Transactions (Texture Reads)     2097152     2097152     2097152
#           1                     stall_memory_throttle                                 Issue Stall Reasons (Memory Throttle)      34.86%      34.86%      34.86%
#           1                        stall_not_selected                                    Issue Stall Reasons (Not Selected)       0.55%       0.55%       0.55%
#           1                 l2_tex_write_transactions                                      L2 Transactions (Texture Writes)    16777216    16777216    16777216
#           1                             flop_count_hp                             Floating Point Operations(Half Precision)           0           0           0
#           1                         flop_count_hp_add                         Floating Point Operations(Half Precision Add)           0           0           0
#           1                         flop_count_hp_mul                          Floating Point Operation(Half Precision Mul)           0           0           0
#           1                         flop_count_hp_fma                         Floating Point Operations(Half Precision FMA)           0           0           0
#           1                                inst_fp_16                                                 HP Instructions(Half)           0           0           0
#           1                                       ipc                                                          Executed IPC    0.216901    0.216901    0.216901
#           1                                issued_ipc                                                            Issued IPC    0.217047    0.217047    0.217047
#           1                    issue_slot_utilization                                                Issue Slot Utilization      10.85%      10.85%      10.85%
#           1                             sm_efficiency                                               Multiprocessor Activity      99.38%      99.38%      99.38%
#           1                        achieved_occupancy                                                    Achieved Occupancy    0.698222    0.698222    0.698222
#           1                  eligible_warps_per_cycle                                       Eligible Warps Per Active Cycle    0.460185    0.460185    0.460185
#           1                        shared_utilization                                             Shared Memory Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                            l2_utilization                                                  L2 Cache Utilization     Low (3)     Low (3)     Low (3)
#           1                           tex_utilization                                             Unified Cache Utilization     Low (1)     Low (1)     Low (1)
#           1                       ldst_fu_utilization                                  Load/Store Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                         cf_fu_utilization                                Control-Flow Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                        tex_fu_utilization                                     Texture Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                    special_fu_utilization                                     Special Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1             half_precision_fu_utilization                              Half-Precision Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1           single_precision_fu_utilization                            Single-Precision Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1           double_precision_fu_utilization                            Double-Precision Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                        flop_hp_efficiency                                            FLOP Efficiency(Peak Half)       0.00%       0.00%       0.00%
#           1                        flop_sp_efficiency                                          FLOP Efficiency(Peak Single)       0.00%       0.00%       0.00%
#           1                        flop_dp_efficiency                                          FLOP Efficiency(Peak Double)       0.00%       0.00%       0.00%
#           1                   sysmem_read_utilization                                        System Memory Read Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                  sysmem_write_utilization                                       System Memory Write Utilization     Low (1)     Low (1)     Low (1)
#           1               pcie_total_data_transmitted                                           PCIe Total Data Transmitted           0           0           0
#           1                  pcie_total_data_received                                              PCIe Total Data Received           0           0           0
#           1                inst_executed_global_loads                              Warp level instructions for global loads      524288      524288      524288
#           1                 inst_executed_local_loads                               Warp level instructions for local loads           0           0           0
#           1                inst_executed_shared_loads                              Warp level instructions for shared loads           0           0           0
#           1               inst_executed_surface_loads                             Warp level instructions for surface loads           0           0           0
#           1               inst_executed_global_stores                             Warp level instructions for global stores      524288      524288      524288
#           1                inst_executed_local_stores                              Warp level instructions for local stores           0           0           0
#           1               inst_executed_shared_stores                             Warp level instructions for shared stores           0           0           0
#           1              inst_executed_surface_stores                            Warp level instructions for surface stores           0           0           0
#           1              inst_executed_global_atomics                  Warp level instructions for global atom and atom cas           0           0           0
#           1           inst_executed_global_reductions                         Warp level instructions for global reductions           0           0           0
#           1             inst_executed_surface_atomics                 Warp level instructions for surface atom and atom cas           0           0           0
#           1          inst_executed_surface_reductions                        Warp level instructions for surface reductions           0           0           0
#           1              inst_executed_shared_atomics                  Warp level shared instructions for atom and atom CAS           0           0           0
#           1                     inst_executed_tex_ops                                   Warp level instructions for texture           0           0           0
#           1                      l2_global_load_bytes       Bytes read from L2 for misses in Unified Cache for global loads    67108864    67108864    67108864
#           1                       l2_local_load_bytes        Bytes read from L2 for misses in Unified Cache for local loads           0           0           0
#           1                     l2_surface_load_bytes      Bytes read from L2 for misses in Unified Cache for surface loads           0           0           0
#           1                           dram_read_bytes                                Total bytes read from DRAM to L2 cache    75877824    75877824    75877824
#           1                          dram_write_bytes                             Total bytes written from L2 cache to DRAM    76118240    76118240    76118240
#           1               l2_local_global_store_bytes   Bytes written to L2 from Unified Cache for local and global stores.   536870912   536870912   536870912
#           1                 l2_global_reduction_bytes          Bytes written to L2 from Unified cache for global reductions           0           0           0
#           1              l2_global_atomic_store_bytes             Bytes written to L2 from Unified cache for global atomics           0           0           0
#           1                    l2_surface_store_bytes            Bytes written to L2 from Unified Cache for surface stores.           0           0           0
#           1                l2_surface_reduction_bytes         Bytes written to L2 from Unified Cache for surface reductions           0           0           0
#           1             l2_surface_atomic_store_bytes    Bytes transferred between Unified Cache and L2 for surface atomics           0           0           0
#           1                      global_load_requests              Total number of global load requests from Multiprocessor     2097152     2097152     2097152
#           1                       local_load_requests               Total number of local load requests from Multiprocessor           0           0           0
#           1                     surface_load_requests             Total number of surface load requests from Multiprocessor           0           0           0
#           1                     global_store_requests             Total number of global store requests from Multiprocessor     2097152     2097152     2097152
#           1                      local_store_requests              Total number of local store requests from Multiprocessor           0           0           0
#           1                    surface_store_requests            Total number of surface store requests from Multiprocessor           0           0           0
#           1                    global_atomic_requests            Total number of global atomic requests from Multiprocessor           0           0           0
#           1                 global_reduction_requests         Total number of global reduction requests from Multiprocessor           0           0           0
#           1                   surface_atomic_requests           Total number of surface atomic requests from Multiprocessor           0           0           0
#           1                surface_reduction_requests        Total number of surface reduction requests from Multiprocessor           0           0           0
#           1                         sysmem_read_bytes                                              System Memory Read Bytes           0           0           0
#           1                        sysmem_write_bytes                                             System Memory Write Bytes         160         160         160
#           1                           l2_tex_hit_rate                                                     L2 Cache Hit Rate      86.11%      86.11%      86.11%
#           1                     texture_load_requests             Total number of texture Load requests from Multiprocessor           0           0           0
#           1                     unique_warps_launched                                              Number of warps launched      524288      524288      524288

# %%
# !/content/src/transpose 16 32
# Out:
# +++ m = 16 n = 32, CPU Time taken = 0.034000 ms
# grid dim = 1
# +++ m = 16 n = 32, GPU Transpose (Read Rows, Store Cols) Time taken = 0.113472 ms
# +++ m = 16 n = 32, GPU Transpose (Read Cols, Store Rows) Time taken = 0.025088 ms

# %%
# !/content/src/transpose 2048 2048 old
# Out:
# +++ m = 2048 n = 2048, CPU Time taken = 75.434000 ms
# grid dim = 64
# +++ m = 2048 n = 2048, GPU Transpose (Read Rows, Store Cols) Time taken = 0.297600 ms
# +++ m = 2048 n = 2048, GPU Transpose (Read Cols, Store Rows) Time taken = 0.298752 ms

# %%
# !/content/src/transpose 2048 2048
# Out:
# +++ m = 2048 n = 2048, CPU Time taken = 123.055000 ms
# grid dim = 64
# +++ m = 2048 n = 2048, GPU Transpose (Read Rows, Store Cols) Time taken = 0.941664 ms
# +++ m = 2048 n = 2048, GPU Transpose (Read Cols, Store Rows) Time taken = 1.393664 ms

# %%
# !/content/src/transpose 512 512 old
# Out:
# +++ m = 512 n = 512, CPU Time taken = 2.600000 ms
# grid dim = 16
# +++ m = 512 n = 512, GPU Transpose (Read Rows, Store Cols) Time taken = 0.032192 ms
# +++ m = 512 n = 512, GPU Transpose (Read Cols, Store Rows) Time taken = 0.018080 ms

# %%
# !/content/src/transpose 512 512 old
# Out:
# +++ m = 512 n = 512, CPU Time taken = 6.556000 ms
# grid dim = 16
# +++ m = 512 n = 512, GPU Transpose (Read Rows, Store Cols) Time taken = 0.142432 ms
# +++ m = 512 n = 512, GPU Transpose (Read Cols, Store Rows) Time taken = 0.114848 ms

# %%
# !/content/src/transpose 4096 4096 old
# Out:
# +++ m = 4096 n = 4096, CPU Time taken = 511.065000 ms
# grid dim = 128
# +++ m = 4096 n = 4096, GPU Transpose (Read Rows, Store Cols) Time taken = 3.163520 ms
# +++ m = 4096 n = 4096, GPU Transpose (Read Cols, Store Rows) Time taken = 5.492896 ms

# %%
# !/content/src/transpose 4096 4096
# Out:
# +++ Name : Tesla P4
#     Total global memory : 7981694976 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM :98304 bytes
#     Total registers per block : 65536 bytes
#     Warp size : 32
# +++ m = 4096 n = 4096, CPU Time taken = 371.211000 ms
# +++ m = 4096 n = 4096, GPU Transpose (Read Rows, Store Cols) Time taken = 2.497568 ms
# +++ m = 4096 n = 4096, GPU Transpose (Read Cols, Store Rows) Time taken = 1.671328 ms
# +++ m = 4096 n = 4096, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 0.937568 ms
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 1.523840 ms
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 0.993024 ms

# %%
# !nvidia-smi
# Out:
# Thu Apr 16 14:12:47 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !nvidia-smi
# Out:
# Tue Apr 14 06:03:38 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !nvidia-smi
# Out:
# Mon Apr 13 05:57:49 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !/content/src/transpose 512 512
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 512 n = 512, CPU Time taken = 6.842000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (16, 16)
# +++ m = 512 n = 512, GPU Transpose (Read Rows, Store Cols) Time taken = 0.182336 ms
# +++ m = 512 n = 512, GPU Transpose (Read Cols, Store Rows) Time taken = 0.118592 ms
# +++ m = 512 n = 512, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 0.045952 ms [Reference Time]
# +++ m = 512 n = 512, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 0.068128 ms
# +++ m = 512 n = 512, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 0.046784 ms
# +++ m = 512 n = 512, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 0.062048 ms
# +++ m = 512 n = 512, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 0.044864 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (16, 32)
# +++ m = 512 n = 512, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 0.052576 ms
# +++ m = 512 n = 512, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 0.052480 ms

# %%
# !/content/src/transpose 1024 1024
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 1024 n = 1024, CPU Time taken = 36.665000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (32, 32)
# +++ m = 1024 n = 1024, GPU Transpose (Read Rows, Store Cols) Time taken = 0.334784 ms
# +++ m = 1024 n = 1024, GPU Transpose (Read Cols, Store Rows) Time taken = 0.372704 ms
# +++ m = 1024 n = 1024, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 0.109888 ms [Reference Time]
# +++ m = 1024 n = 1024, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 0.178880 ms
# +++ m = 1024 n = 1024, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 0.127264 ms
# +++ m = 1024 n = 1024, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 0.179808 ms
# +++ m = 1024 n = 1024, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 0.115840 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (32, 64)
# +++ m = 1024 n = 1024, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 0.133408 ms
# +++ m = 1024 n = 1024, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 0.118560 ms

# %%
# !/content/src/transpose 2048 2048
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 2048 n = 2048, CPU Time taken = 135.685000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (64, 64)
# +++ m = 2048 n = 2048, GPU Transpose (Read Rows, Store Cols) Time taken = 0.869728 ms
# +++ m = 2048 n = 2048, GPU Transpose (Read Cols, Store Rows) Time taken = 1.410976 ms
# +++ m = 2048 n = 2048, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 0.383552 ms [Reference Time]
# +++ m = 2048 n = 2048, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 0.650624 ms
# +++ m = 2048 n = 2048, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 0.399296 ms
# +++ m = 2048 n = 2048, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 0.655104 ms
# +++ m = 2048 n = 2048, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 0.404960 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (64, 128)
# +++ m = 2048 n = 2048, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 0.459072 ms
# +++ m = 2048 n = 2048, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 0.413600 ms

# %%
# !/content/src/transpose 4096 4096
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 4096 n = 4096, CPU Time taken = 571.516000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (128, 128)
# +++ m = 4096 n = 4096, GPU Transpose (Read Rows, Store Cols) Time taken = 3.163520 ms
# +++ m = 4096 n = 4096, GPU Transpose (Read Cols, Store Rows) Time taken = 5.527008 ms
# +++ m = 4096 n = 4096, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 1.385952 ms [Reference Time]
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 2.508064 ms
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 1.478880 ms
# +++ m = 4096 n = 4096, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 2.508960 ms
# +++ m = 4096 n = 4096, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 1.483168 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (128, 256)
# +++ m = 4096 n = 4096, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 1.733408 ms
# +++ m = 4096 n = 4096, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 1.534688 ms

# %%
# !/content/src/transpose 8192 8192
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 8192 n = 8192, CPU Time taken = 2364.602000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (256, 256)
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 12.302528 ms
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 22.016672 ms
# +++ m = 8192 n = 8192, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 5.528704 ms [Reference Time]
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 9.959264 ms
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 6.037600 ms
# +++ m = 8192 n = 8192, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 9.954592 ms
# +++ m = 8192 n = 8192, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 6.018528 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (256, 512)
# +++ m = 8192 n = 8192, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 6.885472 ms
# +++ m = 8192 n = 8192, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 6.314496 ms

# %%
# !/content/src/transpose 3200 3200
# Out:
# +++ Name : Tesla K80
#     Total global memory : 11996954624 bytes
#     Total shared memory per block : 49152 bytes
#     Total shared memory per SM : 114688 bytes
#     Memory bus width : 384 bits
#     Memory clock rate : 2505000 kHz
#     Warp size : 32
# +++ m = 3200 n = 3200, CPU Time taken = 301.519000 ms
# +++ Block Dim = (32, 32)
#     Grid Dim = (100, 100)
# +++ m = 3200 n = 3200, GPU Transpose (Read Rows, Store Cols) Time taken = 1.993088 ms
# +++ m = 3200 n = 3200, GPU Transpose (Read Cols, Store Rows) Time taken = 3.364128 ms
# +++ m = 3200 n = 3200, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 0.923872 ms [Reference Time]
# +++ m = 3200 n = 3200, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 1.535904 ms
# +++ m = 3200 n = 3200, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 0.971904 ms
# +++ m = 3200 n = 3200, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 1.541632 ms
# +++ m = 3200 n = 3200, GPU Transpose (padded 1D sh. mem. no bank conflicts) Time taken = 0.974944 ms
# +++ Block Dim = (32, 16)
#     Grid Dim = (100, 200)
# +++ m = 3200 n = 3200, GPU Transpose (rectangular sh. mem. with bank conflicts) Time taken = 1.109120 ms
# +++ m = 3200 n = 3200, GPU Transpose (rectangular sh. mem. with no bank conflicts) Time taken = 0.990208 ms

# %%
# !nvprof --events warps_launched,local_load --metrics all /content/src/transpose 4096 4096 #Tesla K-80 Profiled
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (57 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (58 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (59 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (60 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1343==
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (done)
# +++ m = 4096 n = 4096, GPU Transpose (Read Rows, Store Cols) Time taken = 1294.274658 ms
# ==1343== Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (1 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (2 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (3 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (4 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (5 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (6 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (7 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (8 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (9 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (10 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (11 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1343==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (12 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (13 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (14 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (15 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (16 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (17 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (18 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (19 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (20 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (21 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (22 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (23 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (24 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (25 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (26 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (27 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (28 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (29 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (30 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (31 of 60)...
# 	rocache_gld_inst_8bit
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (33 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (34 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (35 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (36 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (37 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (38 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (39 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (40 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (41 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (42 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (44 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (45 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (46 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (47 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (48 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (49 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (50 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (51 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (52 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (53 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (54 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (55 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (56 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (57 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (58 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (59 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (60 of 60)...
# 	4 internal events
# ==1343==
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (done)
# +++ m = 4096 n = 4096, GPU Transpose (Read Cols, Store Rows) Time taken = 1375.318237 ms
# ==1343== Replaying kernel "gpuCopy(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (2 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (3 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (4 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (5 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (6 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (7 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (8 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (9 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (10 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (11 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (12 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (13 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (14 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (15 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (16 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (17 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (18 of 60)...
# 	rocache_gld_inst_8bit
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (19 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (20 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (21 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (22 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (23 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (24 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1343==
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (25 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (26 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (27 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (28 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (29 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (30 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (31 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (33 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (34 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (35 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (36 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (37 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (38 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (39 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (40 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (41 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (42 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (44 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (45 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (46 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (47 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (48 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (49 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (50 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (51 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (52 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (53 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (54 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (55 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (56 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (57 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (58 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (59 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (60 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1343==
# Replaying kernel "gpuCopy(float*, float*, int, int)" (done)
# +++ m = 4096 n = 4096, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 1244.905640 ms [Reference Time]
# ==1343== Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (2 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (3 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (4 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1343==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (5 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (6 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (7 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (8 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (9 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (10 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (11 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (12 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (13 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (14 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (15 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (16 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (17 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (18 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (19 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (20 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (21 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (22 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (23 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (24 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (25 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (26 of 60)...
# 	rocache_gld_inst_8bit
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (27 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (28 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (29 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (30 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (31 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (32 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (33 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (34 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (35 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (36 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (37 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (38 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (39 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (41 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (42 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (44 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (45 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (46 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (47 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (48 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (49 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (50 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (51 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (52 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (53 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (54 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (55 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (56 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (57 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (58 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (59 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (60 of 60)...
# 	1 internal events
# ==1343==
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (done)
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 1359.431152 ms
# ==1343== Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (1 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (2 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (3 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (4 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (5 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (6 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (7 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (8 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (9 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1343==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (10 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (11 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (12 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (13 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (15 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (16 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (18 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (19 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (20 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (21 of 60)...
# 	rocache_gld_inst_8bit
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (22 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (23 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (24 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (25 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (26 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (27 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (28 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (29 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (30 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (31 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (32 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (33 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (34 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (35 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (36 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (37 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (38 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (39 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (40 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (41 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (42 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (44 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (45 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (46 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (47 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (48 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (49 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (50 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (51 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (52 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (53 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (54 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (55 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (56 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (57 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (58 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (59 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (60 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1343==
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (done)
# +++ m = 4096 n = 4096, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 1285.763794 ms
# ==1343== Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (1 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (2 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_write_l1_sector_queries
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (3 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (4 of 60)...
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (5 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (6 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (7 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (8 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (9 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (10 of 60)...
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (11 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (12 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (13 of 60)...
# 	elapsed_cycles_sm
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (15 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (16 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (18 of 60)...
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	active_cycles
# 	10 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (19 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (20 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1343==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (21 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (22 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (23 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (24 of 60)...
# 	l2_subp0_read_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (25 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (26 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (27 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (28 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (29 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (30 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_write_l1_sector_queries
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1343==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (31 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (32 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1343==
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (33 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (34 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (35 of 60)...
# 	2 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (36 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (37 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (38 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (39 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1343==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (40 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (41 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (42 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (44 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (45 of 60)...
# 	rocache_gld_inst_8bit
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (46 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (47 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (48 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (49 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (50 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (51 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (52 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (53 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (54 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (56 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_write_l1_sector_queries
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1343==
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (57 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (58 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (59 of 60)...
# 	1 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (60 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1343==
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (done)
# +++ m = 4096 n = 4096, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 1349.975220 ms
# ==1343== Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (1 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (2 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (3 of 60)...
# 	rocache_gld_inst_8bit
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (4 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (5 of 60)...
# 	4 internal events
# ==1343==
#
#
# Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (6 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1343==
#
#
# ...
#           1                      dram_read_throughput                         Device Memory Read Throughput  30.051GB/s  30.051GB/s  30.051GB/s
#           1                     dram_write_throughput                        Device Memory Write Throughput  31.226GB/s  31.226GB/s  31.226GB/s
#           1                            gst_throughput                               Global Store Throughput  25.227GB/s  25.227GB/s  25.227GB/s
#           1                            gld_throughput                                Global Load Throughput  25.227GB/s  25.227GB/s  25.227GB/s
#           1                     local_replay_overhead                    Local Memory Cache Replay Overhead    0.000000    0.000000    0.000000
#           1                         shared_efficiency                              Shared Memory Efficiency       5.88%       5.88%       5.88%
#           1                            gld_efficiency                         Global Memory Load Efficiency     100.00%     100.00%     100.00%
#           1                            gst_efficiency                        Global Memory Store Efficiency     100.00%     100.00%     100.00%
#           1                       l2_l1_read_hit_rate                                L2 Hit Rate (L1 Reads)       0.00%       0.00%       0.00%
#           1                  l2_texture_read_hit_rate                           L2 Hit Rate (Texture Reads)       0.00%       0.00%       0.00%
#           1                     l2_l1_read_throughput                              L2 Throughput (L1 Reads)  25.227GB/s  25.227GB/s  25.227GB/s
#           1                l2_texture_read_throughput                         L2 Throughput (Texture Reads)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                     local_memory_overhead                                 Local Memory Overhead       0.00%       0.00%       0.00%
#           1                 warp_execution_efficiency                             Warp Execution Efficiency     100.00%     100.00%     100.00%
#           1               nc_gld_requested_throughput         Requested Non-Coherent Global Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                                issued_ipc                                            Issued IPC    1.505572    1.505572    1.505572
#           1                             inst_per_warp                                 Instructions per warp   34.000000   34.000000   34.000000
#           1                    issue_slot_utilization                                Issue Slot Utilization      33.21%      33.21%      33.21%
#           1       local_load_transactions_per_request            Local Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1      local_store_transactions_per_request           Local Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1      shared_load_transactions_per_request           Shared Memory Load Transactions Per Request   16.000000   16.000000   16.000000
#           1     shared_store_transactions_per_request          Shared Memory Store Transactions Per Request    1.000000    1.000000    1.000000
#           1              gld_transactions_per_request                  Global Load Transactions Per Request    1.000000    1.000000    1.000000
#           1              gst_transactions_per_request                 Global Store Transactions Per Request    1.000000    1.000000    1.000000
#           1                   local_load_transactions                               Local Load Transactions           0           0           0
#           1                  local_store_transactions                              Local Store Transactions           0           0           0
#           1                  shared_load_transactions                              Shared Load Transactions     8388608     8388608     8388608
#           1                 shared_store_transactions                             Shared Store Transactions      524288      524288      524288
#           1                          gld_transactions                              Global Load Transactions      524288      524288      524288
#           1                          gst_transactions                             Global Store Transactions      524288      524288      524288
#           1                  sysmem_read_transactions                       System Memory Read Transactions           0           0           0
#           1                 sysmem_write_transactions                      System Memory Write Transactions           5           5           5
#           1                    tex_cache_transactions                            Texture Cache Transactions           0           0           0
#           1                    dram_read_transactions                       Device Memory Read Transactions     2498143     2498143     2498143
#           1                   dram_write_transactions                      Device Memory Write Transactions     2595859     2595859     2595859
#           1                      l2_read_transactions                                  L2 Read Transactions     2097263     2097263     2097263
#           1                     l2_write_transactions                                 L2 Write Transactions     2097157     2097157     2097157
#           1                     local_load_throughput                          Local Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    local_store_throughput                         Local Memory Store Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    shared_load_throughput                         Shared Memory Load Throughput  807.27GB/s  807.27GB/s  807.27GB/s
#           1                   shared_store_throughput                        Shared Memory Store Throughput  50.455GB/s  50.455GB/s  50.455GB/s
#           1                        l2_read_throughput                                 L2 Throughput (Reads)  25.229GB/s  25.229GB/s  25.229GB/s
#           1                       l2_write_throughput                                L2 Throughput (Writes)  25.227GB/s  25.227GB/s  25.227GB/s
#           1                    sysmem_read_throughput                         System Memory Read Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   sysmem_write_throughput                        System Memory Write Throughput  63.067KB/s  63.067KB/s  63.066KB/s
#           1         warp_nonpred_execution_efficiency              Warp Non-Predicated Execution Efficiency      94.12%      94.12%      94.12%
#           1                                 cf_issued                      Issued Control-Flow Instructions     2631318     2631318     2631318
#           1                               cf_executed                    Executed Control-Flow Instructions     2621440     2621440     2621440
#           1                               ldst_issued                        Issued Load/Store Instructions    10549045    10549045    10549045
#           1                             ldst_executed                      Executed Load/Store Instructions     2097152     2097152     2097152
#           1                             flop_count_sp           Floating Point Operations(Single Precision)           0           0           0
#           1                         flop_count_sp_add       Floating Point Operations(Single Precision Add)           0           0           0
#           1                         flop_count_sp_mul        Floating Point Operation(Single Precision Mul)           0           0           0
#           1                         flop_count_sp_fma       Floating Point Operations(Single Precision FMA)           0           0           0
#           1                             flop_count_dp           Floating Point Operations(Double Precision)           0           0           0
#           1                         flop_count_dp_add       Floating Point Operations(Double Precision Add)           0           0           0
#           1                         flop_count_dp_mul       Floating Point Operations(Double Precision Mul)           0           0           0
#           1                         flop_count_dp_fma       Floating Point Operations(Double Precision FMA)           0           0           0
#           1                     flop_count_sp_special   Floating Point Operations(Single Precision Special)           0           0           0
#           1                          stall_inst_fetch              Issue Stall Reasons (Instructions Fetch)       2.65%       2.65%       2.65%
#           1                     stall_exec_dependency            Issue Stall Reasons (Execution Dependency)      12.47%      12.47%      12.47%
#           1                   stall_memory_dependency                    Issue Stall Reasons (Data Request)      16.76%      16.76%      16.76%
#           1                             stall_texture                         Issue Stall Reasons (Texture)       0.00%       0.00%       0.00%
#           1                                stall_sync                 Issue Stall Reasons (Synchronization)       5.07%       5.07%       5.07%
#           1                               stall_other                           Issue Stall Reasons (Other)       1.48%       1.48%       1.48%
#           1                     l1_shared_utilization                          L1/Shared Memory Utilization     Mid (6)     Mid (6)     Mid (6)
#           1                            l2_utilization                                  L2 Cache Utilization     Low (1)     Low (1)     Low (1)
#           1                           tex_utilization                             Texture Cache Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                          dram_utilization                             Device Memory Utilization     Low (3)     Low (3)     Low (3)
#           1                        sysmem_utilization                             System Memory Utilization     Low (1)     Low (1)     Low (1)
#           1                       ldst_fu_utilization                  Load/Store Function Unit Utilization     Mid (6)     Mid (6)     Mid (6)
#           1                        alu_fu_utilization                  Arithmetic Function Unit Utilization     Low (3)     Low (3)     Low (3)
#           1                         cf_fu_utilization                Control-Flow Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                        tex_fu_utilization                     Texture Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                             inst_executed                                 Instructions Executed    17825792    17825792    17825792
#           1                               inst_issued                                   Instructions Issued    26814849    26814849    26814849
#           1                               issue_slots                                           Issue Slots    23659335    23659335    23659335
#           1                     nc_l2_read_throughput                    L2 Throughput (Non-Coherent Reads)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   nc_l2_read_transactions                     L2 Non-Coherent Read Transactions           0           0           0
#           1                  nc_cache_global_hit_rate                          Non-Coherent Global Hit Rate       0.00%       0.00%       0.00%
#           1                         nc_gld_throughput            Non-Coherent Global Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                         nc_gld_efficiency                   Non-Coherent Global Load Efficiency       0.00%       0.00%       0.00%
#           1                      l2_atomic_throughput                       L2 Throughput (Atomic requests)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                                inst_fp_32                               FP Instructions(Single)           0           0           0
#           1                                inst_fp_64                               FP Instructions(Double)           0           0           0
#           1                              inst_integer                                  Integer Instructions   301989888   301989888   301989888
#           1                          inst_bit_convert                              Bit-Convert Instructions           0           0           0
#           1                              inst_control                             Control-Flow Instructions    16777216    16777216    16777216
#           1                        inst_compute_ld_st                               Load/Store Instructions    67108864    67108864    67108864
#           1                                 inst_misc                                     Misc Instructions   134217728   134217728   134217728
#           1           inst_inter_thread_communication                             Inter-Thread Instructions           0           0           0
#           1                    atomic_replay_overhead                                Atomic Replay Overhead    0.000000    0.000000    0.000000
#           1                       atomic_transactions                                   Atomic Transactions           0           0           0
#           1           atomic_transactions_per_request                       Atomic Transactions Per Request    0.000000    0.000000    0.000000
#           1                   sysmem_read_utilization                        System Memory Read Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                  sysmem_write_utilization                       System Memory Write Utilization     Low (1)     Low (1)     Low (1)
#           1                   l2_l1_read_transactions               L2 Read Transactions (L1 read requests)     2097152     2097152     2097152
#           1                  l2_l1_write_transactions             L2 Write Transactions (L1 write requests)     2097152     2097152     2097152
#           1                  l2_tex_read_transactions                       L2 Transactions (Texture Reads)           0           0           0
#           1                    l2_l1_write_throughput                             L2 Throughput (L1 Writes)  25.227GB/s  25.227GB/s  25.227GB/s
#           1                    l2_atomic_transactions                     L2 Transactions (Atomic requests)           0           0           0
#           1                          ecc_transactions                                      ECC Transactions      899666      899666      899666
#           1                            ecc_throughput                                        ECC Throughput  10.822GB/s  10.822GB/s  10.822GB/s
#           1                           stall_pipe_busy                       Issue Stall Reasons (Pipe Busy)      35.45%      35.45%      35.45%
#           1          stall_constant_memory_dependency              Issue Stall Reasons (Immediate constant)       0.02%       0.02%       0.02%
#           1                        flop_sp_efficiency                          FLOP Efficiency(Peak Single)       0.00%       0.00%       0.00%
#           1                        flop_dp_efficiency                          FLOP Efficiency(Peak Double)       0.00%       0.00%       0.00%
#           1                     stall_memory_throttle                 Issue Stall Reasons (Memory Throttle)      13.94%      13.94%      13.94%
#           1                        stall_not_selected                    Issue Stall Reasons (Not Selected)      12.18%      12.18%      12.18%
#           1                  eligible_warps_per_cycle                       Eligible Warps Per Active Cycle    7.954559    7.954559    7.954559
#           1                         atomic_throughput                                     Atomic Throughput  0.00000B/s  0.00000B/s  0.00000B/s

# %%
# !nvprof --events warps_launched,local_load --metrics all /content/src/transpose 8192 8192 #Tesla K-80 Profiled
# Out:
# Streaming output truncated to the last 5000 lines.
# 	rocache_gld_inst_16bit
# ==1365==
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (57 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (58 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (59 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (60 of 60)...
# 	4 internal events
# ==1365==
# Replaying kernel "gpuTransposeRow(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (Read Rows, Store Cols) Time taken = 3005.263916 ms
# ==1365== Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (2 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (3 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (4 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (5 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (6 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (7 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (8 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (9 of 60)...
# 	l2_subp3_write_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (10 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (11 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (12 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (13 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (14 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (15 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (16 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (17 of 60)...
# 	elapsed_cycles_sm
# 	l2_subp0_read_l1_sector_queries
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (18 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (19 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (20 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (21 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (22 of 60)...
# 	l2_subp0_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (23 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (24 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (25 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (26 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1365==
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (27 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (28 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (29 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (30 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (31 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (33 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	active_cycles
# 	10 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (34 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (35 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (36 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (37 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (38 of 60)...
# 	rocache_gld_inst_8bit
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (39 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (40 of 60)...
# 	l2_subp1_write_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (41 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (42 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (43 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (44 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (45 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (46 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (47 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (48 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (49 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (50 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (51 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (52 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (53 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (54 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (55 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (56 of 60)...
# 	l2_subp2_write_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (57 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (58 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (59 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (60 of 60)...
# 	4 internal events
# ==1365==
# Replaying kernel "gpuTransposeCol(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (Read Cols, Store Rows) Time taken = 3494.128662 ms
# ==1365== Replaying kernel "gpuCopy(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (2 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (3 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (4 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (5 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (6 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (7 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (8 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (9 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (10 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1365==
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (11 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (12 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (13 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (15 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (16 of 60)...
# 	elapsed_cycles_sm
# 	l2_subp0_read_l1_sector_queries
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (17 of 60)...
# 	l2_subp0_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (18 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (19 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (20 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (21 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (22 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (23 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (24 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (25 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (26 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (27 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (28 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (29 of 60)...
# 	l2_subp2_write_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (30 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (31 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (32 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (33 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (34 of 60)...
# 	l2_subp1_write_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (35 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (36 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (37 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (38 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (39 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (41 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (42 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (44 of 60)...
# 	l2_subp3_write_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (45 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (46 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (47 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (48 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (49 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (50 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (51 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (52 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (53 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (54 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (55 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (56 of 60)...
# 	rocache_gld_inst_8bit
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (57 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (58 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	active_cycles
# 	10 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (59 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuCopy(float*, float*, int, int)" (60 of 60)...
# 	1 internal events
# ==1365==
# Replaying kernel "gpuCopy(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU simple copy (square sh. mem. no bank conflicts) Time taken = 2899.702393 ms [Reference Time]
# ==1365== Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (1 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (2 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (3 of 60)...
# 	l2_subp3_write_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (4 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (5 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (6 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (7 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (8 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (9 of 60)...
# 	rocache_gld_inst_8bit
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (10 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (11 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (12 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (13 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (14 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (15 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (16 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (17 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (18 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (19 of 60)...
# 	l2_subp2_write_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (20 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (21 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (22 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (23 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (24 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (25 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (26 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (27 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (28 of 60)...
# 	l2_subp0_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (29 of 60)...
# 	elapsed_cycles_sm
# 	l2_subp0_read_l1_sector_queries
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (30 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (31 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (33 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (34 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (35 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (36 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (37 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (38 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1365==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (39 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (41 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (42 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (43 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (44 of 60)...
# 	l2_subp1_write_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (45 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (46 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (47 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (48 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (49 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (50 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (51 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (52 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (53 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	active_cycles
# 	10 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (54 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (55 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (56 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (57 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (58 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (59 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (60 of 60)...
# 	2 internal events
# ==1365==
# Replaying kernel "gpuTransposeCoalesced(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. with bank conflicts) Time taken = 3282.798340 ms
# ==1365== Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (1 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (2 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	active_cycles
# 	10 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (3 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (4 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (5 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (6 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (7 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (8 of 60)...
# 	l2_subp0_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (9 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (10 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (11 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (12 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (13 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (14 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (15 of 60)...
# 	l2_subp2_write_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (16 of 60)...
# 	l2_subp3_write_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (17 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (18 of 60)...
# 	elapsed_cycles_sm
# 	l2_subp0_read_l1_sector_queries
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (19 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (20 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (21 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (22 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (23 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (24 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (25 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (26 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (27 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (28 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (29 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (30 of 60)...
# 	l2_subp1_write_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (31 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (32 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (33 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (34 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (35 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (36 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (37 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (38 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (39 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (40 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (41 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (42 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (43 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (44 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (45 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (46 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (47 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (48 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (49 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (50 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (51 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (52 of 60)...
# 	rocache_gld_inst_8bit
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (53 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1365==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (54 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (55 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (56 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (57 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (58 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (59 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (60 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1365==
# Replaying kernel "gpuTransposeCoalescedNoBC(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (square sh. mem. no bank conflicts) Time taken = 3070.773438 ms
# ==1365== Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (1 of 60)...
# 	l2_subp3_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (2 of 60)...
# 	l2_subp1_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (3 of 60)...
# 	l2_subp2_read_l1_sector_queries
# 	inst_executed
# 	inst_issued1
# 	inst_issued2
# 	thread_inst_executed
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (4 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (5 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (6 of 60)...
# 	l2_subp3_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (7 of 60)...
# 	l2_subp2_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (8 of 60)...
# 	elapsed_cycles_sm
# 	l2_subp0_read_l1_sector_queries
# 	fb_subp0_write_sectors
# 	fb_subp0_read_sectors
# 	inst_issued1
# 	inst_issued2
# 	active_cycles
# 	8 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (9 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (10 of 60)...
# 	l2_subp2_write_l1_sector_queries
# 	inst_executed
# 	shared_load_replay
# 	shared_store_replay
# 	global_ld_mem_divergence_replays
# 	global_st_mem_divergence_replays
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (11 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (12 of 60)...
# 	l2_subp0_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (13 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (14 of 60)...
# 	rocache_gld_inst_128bit
# 	rocache_gld_inst_64bit
# 	rocache_gld_inst_32bit
# 	rocache_gld_inst_16bit
# ==1365==
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (15 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (16 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (17 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (18 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (19 of 60)...
# 	l2_subp0_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (20 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (21 of 60)...
# 	l2_subp3_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (22 of 60)...
# 	l2_subp3_write_l1_sector_queries
# 	inst_executed
# 	l1_local_load_miss
# 	l1_local_store_miss
# 	local_load_transactions
# 	local_load
# 	local_store_transactions
# 	local_store
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (23 of 60)...
# 	l2_subp2_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (24 of 60)...
# 	l2_subp1_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (25 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (26 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (27 of 60)...
# 	l2_subp0_write_l1_sector_queries
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	inst_executed
# 	active_cycles
# 	shared_load_replay
# 	warps_launched
# 	not_predicated_off_thread_inst_executed
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (28 of 60)...
# 	l2_subp0_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (29 of 60)...
# 	l2_subp1_read_l1_sector_queries
# 	fb_subp1_write_sectors
# 	fb_subp1_read_sectors
# 	active_cycles
# 	10 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (30 of 60)...
# 	l2_subp1_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (31 of 60)...
# 	l2_subp2_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (32 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (33 of 60)...
# 	l2_subp0_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (34 of 60)...
# 	tex0_cache_sector_misses
# 	tex2_cache_sector_misses
# 	l2_subp2_read_sector_misses
# 	l2_subp2_write_sector_misses
# 	l1_local_load_hit
# 	l1_local_load_miss
# 	l1_local_store_hit
# 	5 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (35 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (36 of 60)...
# 	l2_subp1_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (37 of 60)...
# 	l2_subp2_read_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (38 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (39 of 60)...
# 	l2_subp1_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (40 of 60)...
# 	l2_subp1_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (41 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (42 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (43 of 60)...
# 	tex1_cache_sector_misses
# 	tex3_cache_sector_misses
# 	l2_subp3_read_sector_misses
# 	l2_subp3_write_sector_misses
# 	l1_local_store_hit
# 	global_store_transaction
# 	6 internal events
# ==1365==
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (44 of 60)...
# 	l2_subp0_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (45 of 60)...
# 	l2_subp2_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (46 of 60)...
# 	l2_subp1_write_l1_sector_queries
# 	active_warps
# 	active_cycles
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (47 of 60)...
# 	tex1_cache_sector_queries
# 	tex3_cache_sector_queries
# 	l2_subp1_read_sector_misses
# 	l2_subp1_write_sector_misses
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	uncached_global_load_transaction
# 	l1_local_load_hit
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (48 of 60)...
# 	2 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (49 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (50 of 60)...
# 	l2_subp3_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (51 of 60)...
# 	l2_subp0_total_read_sector_queries
# 	4 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (52 of 60)...
# 	rocache_gld_inst_8bit
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (53 of 60)...
# 	l2_subp2_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (54 of 60)...
# 	tex0_cache_sector_queries
# 	tex2_cache_sector_queries
# 	l2_subp0_read_sector_misses
# 	l2_subp0_write_sector_misses
# 	l1_shared_load_transactions
# 	shared_load
# 	l1_shared_store_transactions
# 	shared_store
# 	l1_global_load_hit
# 	l1_global_load_miss
# 	2 internal events
# ==1365==
#
#
#
#
#
#
#
#
#
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (55 of 60)...
# 	l2_subp3_read_tex_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (56 of 60)...
# 	l2_subp3_total_write_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (57 of 60)...
# 	l2_subp0_write_sysmem_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (58 of 60)...
# 	l2_subp3_total_read_sector_queries
# 	3 internal events
# ==1365==
#
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (59 of 60)...
# 	l2_subp2_read_tex_sector_queries
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (60 of 60)...
# 	1 internal events
# ==1365==
# Replaying kernel "gpuTransposeCoalesced1D(float*, float*, int, int)" (done)
# +++ m = 8192 n = 8192, GPU Transpose (1D sh. mem. with bank conflicts) Time taken = 3289.269043 ms
# ==1365== Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (1 of 60)...
# 	l2_subp1_read_l1_hit_sectors
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (2 of 60)...
# 	1 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (3 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (4 of 60)...
# 	4 internal events
# ==1365==
#
#
# Replaying kernel "gpuTransposeCoalesced1DNoBC(float*, float*, int, int)" (5 of 60)...
# 	l2_subp3_read_l1_sector_queries
# 	atom_count
# 	atom_cas_count
# 	gred_count
# 	l1_global_load_hit
# 	inst_executed
# 	4 internal events
# ==1365==
#
#
#
#
#
#
#
#
# ...
#           1                      dram_read_throughput                         Device Memory Read Throughput  31.144GB/s  31.144GB/s  31.144GB/s
#           1                     dram_write_throughput                        Device Memory Write Throughput  31.493GB/s  31.493GB/s  31.493GB/s
#           1                            gst_throughput                               Global Store Throughput  25.194GB/s  25.194GB/s  25.194GB/s
#           1                            gld_throughput                                Global Load Throughput  25.194GB/s  25.194GB/s  25.194GB/s
#           1                     local_replay_overhead                    Local Memory Cache Replay Overhead    0.000000    0.000000    0.000000
#           1                         shared_efficiency                              Shared Memory Efficiency       5.88%       5.88%       5.88%
#           1                            gld_efficiency                         Global Memory Load Efficiency     100.00%     100.00%     100.00%
#           1                            gst_efficiency                        Global Memory Store Efficiency     100.00%     100.00%     100.00%
#           1                       l2_l1_read_hit_rate                                L2 Hit Rate (L1 Reads)       0.00%       0.00%       0.00%
#           1                  l2_texture_read_hit_rate                           L2 Hit Rate (Texture Reads)       0.00%       0.00%       0.00%
#           1                     l2_l1_read_throughput                              L2 Throughput (L1 Reads)  25.194GB/s  25.194GB/s  25.194GB/s
#           1                l2_texture_read_throughput                         L2 Throughput (Texture Reads)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                     local_memory_overhead                                 Local Memory Overhead       0.00%       0.00%       0.00%
#           1                 warp_execution_efficiency                             Warp Execution Efficiency     100.00%     100.00%     100.00%
#           1               nc_gld_requested_throughput         Requested Non-Coherent Global Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                                issued_ipc                                            Issued IPC    1.502550    1.502550    1.502550
#           1                             inst_per_warp                                 Instructions per warp   34.000000   34.000000   34.000000
#           1                    issue_slot_utilization                                Issue Slot Utilization      33.14%      33.14%      33.14%
#           1       local_load_transactions_per_request            Local Memory Load Transactions Per Request    0.000000    0.000000    0.000000
#           1      local_store_transactions_per_request           Local Memory Store Transactions Per Request    0.000000    0.000000    0.000000
#           1      shared_load_transactions_per_request           Shared Memory Load Transactions Per Request   16.000000   16.000000   16.000000
#           1     shared_store_transactions_per_request          Shared Memory Store Transactions Per Request    1.000029    1.000029    1.000029
#           1              gld_transactions_per_request                  Global Load Transactions Per Request    1.000000    1.000000    1.000000
#           1              gst_transactions_per_request                 Global Store Transactions Per Request    1.000000    1.000000    1.000000
#           1                   local_load_transactions                               Local Load Transactions           0           0           0
#           1                  local_store_transactions                              Local Store Transactions           0           0           0
#           1                  shared_load_transactions                              Shared Load Transactions    33554432    33554432    33554432
#           1                 shared_store_transactions                             Shared Store Transactions     2097212     2097212     2097212
#           1                          gld_transactions                              Global Load Transactions     2097152     2097152     2097152
#           1                          gst_transactions                             Global Store Transactions     2097152     2097152     2097152
#           1                  sysmem_read_transactions                       System Memory Read Transactions           0           0           0
#           1                 sysmem_write_transactions                      System Memory Write Transactions           1           1           1
#           1                    tex_cache_transactions                            Texture Cache Transactions           0           0           0
#           1                    dram_read_transactions                       Device Memory Read Transactions    10369547    10369547    10369547
#           1                   dram_write_transactions                      Device Memory Write Transactions    10485774    10485774    10485774
#           1                      l2_read_transactions                                  L2 Read Transactions     8388756     8388756     8388756
#           1                     l2_write_transactions                                 L2 Write Transactions     8388622     8388622     8388622
#           1                     local_load_throughput                          Local Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    local_store_throughput                         Local Memory Store Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                    shared_load_throughput                         Shared Memory Load Throughput  806.21GB/s  806.21GB/s  806.21GB/s
#           1                   shared_store_throughput                        Shared Memory Store Throughput  50.390GB/s  50.390GB/s  50.390GB/s
#           1                        l2_read_throughput                                 L2 Throughput (Reads)  25.194GB/s  25.194GB/s  25.194GB/s
#           1                       l2_write_throughput                                L2 Throughput (Writes)  25.194GB/s  25.194GB/s  25.194GB/s
#           1                    sysmem_read_throughput                         System Memory Read Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   sysmem_write_throughput                        System Memory Write Throughput  3.1484KB/s  3.1484KB/s  3.1475KB/s
#           1         warp_nonpred_execution_efficiency              Warp Non-Predicated Execution Efficiency      94.12%      94.12%      94.12%
#           1                                 cf_issued                      Issued Control-Flow Instructions    10528347    10528347    10528347
#           1                               cf_executed                    Executed Control-Flow Instructions    10485760    10485760    10485760
#           1                               ldst_issued                        Issued Load/Store Instructions    42201732    42201732    42201732
#           1                             ldst_executed                      Executed Load/Store Instructions     8388608     8388608     8388608
#           1                             flop_count_sp           Floating Point Operations(Single Precision)           0           0           0
#           1                         flop_count_sp_add       Floating Point Operations(Single Precision Add)           0           0           0
#           1                         flop_count_sp_mul        Floating Point Operation(Single Precision Mul)           0           0           0
#           1                         flop_count_sp_fma       Floating Point Operations(Single Precision FMA)           0           0           0
#           1                             flop_count_dp           Floating Point Operations(Double Precision)           0           0           0
#           1                         flop_count_dp_add       Floating Point Operations(Double Precision Add)           0           0           0
#           1                         flop_count_dp_mul       Floating Point Operations(Double Precision Mul)           0           0           0
#           1                         flop_count_dp_fma       Floating Point Operations(Double Precision FMA)           0           0           0
#           1                     flop_count_sp_special   Floating Point Operations(Single Precision Special)           0           0           0
#           1                          stall_inst_fetch              Issue Stall Reasons (Instructions Fetch)       2.59%       2.59%       2.59%
#           1                     stall_exec_dependency            Issue Stall Reasons (Execution Dependency)      12.44%      12.44%      12.44%
#           1                   stall_memory_dependency                    Issue Stall Reasons (Data Request)      16.90%      16.90%      16.90%
#           1                             stall_texture                         Issue Stall Reasons (Texture)       0.00%       0.00%       0.00%
#           1                                stall_sync                 Issue Stall Reasons (Synchronization)       5.72%       5.72%       5.72%
#           1                               stall_other                           Issue Stall Reasons (Other)       1.48%       1.48%       1.48%
#           1                     l1_shared_utilization                          L1/Shared Memory Utilization     Mid (6)     Mid (6)     Mid (6)
#           1                            l2_utilization                                  L2 Cache Utilization     Low (1)     Low (1)     Low (1)
#           1                           tex_utilization                             Texture Cache Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                          dram_utilization                             Device Memory Utilization     Low (3)     Low (3)     Low (3)
#           1                        sysmem_utilization                             System Memory Utilization     Low (1)     Low (1)     Low (1)
#           1                       ldst_fu_utilization                  Load/Store Function Unit Utilization     Mid (6)     Mid (6)     Mid (6)
#           1                        alu_fu_utilization                  Arithmetic Function Unit Utilization     Low (3)     Low (3)     Low (3)
#           1                         cf_fu_utilization                Control-Flow Function Unit Utilization     Low (1)     Low (1)     Low (1)
#           1                        tex_fu_utilization                     Texture Function Unit Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                             inst_executed                                 Instructions Executed    71303168    71303168    71303168
#           1                               inst_issued                                   Instructions Issued   107259921   107259921   107259921
#           1                               issue_slots                                           Issue Slots    94633871    94633871    94633871
#           1                     nc_l2_read_throughput                    L2 Throughput (Non-Coherent Reads)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                   nc_l2_read_transactions                     L2 Non-Coherent Read Transactions           0           0           0
#           1                  nc_cache_global_hit_rate                          Non-Coherent Global Hit Rate       0.00%       0.00%       0.00%
#           1                         nc_gld_throughput            Non-Coherent Global Memory Load Throughput  0.00000B/s  0.00000B/s  0.00000B/s
#           1                         nc_gld_efficiency                   Non-Coherent Global Load Efficiency       0.00%       0.00%       0.00%
#           1                      l2_atomic_throughput                       L2 Throughput (Atomic requests)  0.00000B/s  0.00000B/s  0.00000B/s
#           1                                inst_fp_32                               FP Instructions(Single)           0           0           0
#           1                                inst_fp_64                               FP Instructions(Double)           0           0           0
#           1                              inst_integer                                  Integer Instructions  1207959552  1207959552  1207959552
#           1                          inst_bit_convert                              Bit-Convert Instructions           0           0           0
#           1                              inst_control                             Control-Flow Instructions    67108864    67108864    67108864
#           1                        inst_compute_ld_st                               Load/Store Instructions   268435456   268435456   268435456
#           1                                 inst_misc                                     Misc Instructions   536870912   536870912   536870912
#           1           inst_inter_thread_communication                             Inter-Thread Instructions           0           0           0
#           1                    atomic_replay_overhead                                Atomic Replay Overhead    0.000000    0.000000    0.000000
#           1                       atomic_transactions                                   Atomic Transactions           0           0           0
#           1           atomic_transactions_per_request                       Atomic Transactions Per Request    0.000000    0.000000    0.000000
#           1                   sysmem_read_utilization                        System Memory Read Utilization    Idle (0)    Idle (0)    Idle (0)
#           1                  sysmem_write_utilization                       System Memory Write Utilization     Low (1)     Low (1)     Low (1)
#           1                   l2_l1_read_transactions               L2 Read Transactions (L1 read requests)     8388608     8388608     8388608
#           1                  l2_l1_write_transactions             L2 Write Transactions (L1 write requests)     8388608     8388608     8388608
#           1                  l2_tex_read_transactions                       L2 Transactions (Texture Reads)           0           0           0
#           1                    l2_l1_write_throughput                             L2 Throughput (L1 Writes)  25.194GB/s  25.194GB/s  25.194GB/s
#           1                    l2_atomic_transactions                     L2 Transactions (Atomic requests)           0           0           0
#           1                          ecc_transactions                                      ECC Transactions     4077728     4077728     4077728
#           1                            ecc_throughput                                        ECC Throughput  12.247GB/s  12.247GB/s  12.247GB/s
#           1                           stall_pipe_busy                       Issue Stall Reasons (Pipe Busy)      34.76%      34.76%      34.76%
#           1          stall_constant_memory_dependency              Issue Stall Reasons (Immediate constant)       0.01%       0.01%       0.01%
#           1                        flop_sp_efficiency                          FLOP Efficiency(Peak Single)       0.00%       0.00%       0.00%
#           1                        flop_dp_efficiency                          FLOP Efficiency(Peak Double)       0.00%       0.00%       0.00%
#           1                     stall_memory_throttle                 Issue Stall Reasons (Memory Throttle)      13.99%      13.99%      13.99%
#           1                        stall_not_selected                    Issue Stall Reasons (Not Selected)      12.11%      12.11%      12.11%
#           1                  eligible_warps_per_cycle                       Eligible Warps Per Active Cycle    7.914386    7.914386    7.914386
#           1                         atomic_throughput                                     Atomic Throughput  0.00000B/s  0.00000B/s  0.00000B/s
